# %%
import numpy as np
import pandas as pd
import os
import dotenv
import psycopg
from sqlalchemy import create_engine

import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output

import plotly.express as px
import plotly.figure_factory as ff

# %%
dotenv.load_dotenv()
POSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')

dbms = 'postgresql'
package = 'psycopg'
user = 'postgres'
password = POSTGRES_PASSWORD
host = 'localhost'
port = '5432'
db = 'contrans'

engine = create_engine(f'{dbms}+{package}://{user}:{password}@{host}:{port}/{db}')

# %%
external_stylesheets = ['https://codepen.io/chriddyp/pen/bWLwgP.css']

# Create features that we need, but won't change depending on what the user does
myquery = '''
SELECT *
FROM members
'''
data = pd.read_sql_query(myquery, con=engine)

# %%
data2 = data[['full_name', 'state_abbrev', 'district_code', 'party']]
data2['party'] = data2['party'].str[0]
display_name = [n + ' (' + p + ', ' + s + '-' + str(d) + ')'
                for n, s, d, p in 
                zip(data2['full_name'], 
                    data2['state_abbrev'],
                    data2['district_code'],
                    data2['party'])]
display_name = [x.replace('-0', '') for x in display_name]
display_name
# Out:
# ['Robert B. Aderholt (R, AL-4)',
#  'Jake Auchincloss (D, MA-4)',
#  'Mark E. Amodei (R, NV-2)',
#  'Alma S. Adams (D, NC-12)',
#  'Pete Aguilar (D, CA-33)',
#  'Rick W. Allen (R, GA-12)',
#  'Jodey C. Arrington (R, TX-19)',
#  'Mark Alford (R, MO-4)',
#  'Gabe Amo (D, RI-1)',
#  'Yassamin Ansari (D, AZ-3)',
#  'Angela D. Alsobrooks (D, MD)',
#  'Sanford D. Bishop, Jr. (D, GA-2)',
#  'Cliff Bentz (R, OR-2)',
#  'Stephanie I. Bice (R, OK-5)',
#  'Lauren Boebert (R, CO-4)',
#  'Tammy Baldwin (D, WI)',
#  'John Boozman (R, AR)',
#  'Marsha Blackburn (R, TN)',
#  'Gus M. Bilirakis (R, FL-12)',
#  'Vern Buchanan (R, FL-16)',
#  'John Barrasso (R, WY)',
#  'Michael F. Bennet (D, CO)',
#  'Richard Blumenthal (D, CT)',
#  'Suzanne Bonamici (D, OR-1)',
#  'Joyce Beatty (D, OH-3)',
#  'Andy Barr (R, KY-6)',
#  'Julia Brownley (D, CA-26)',
#  'Ami Bera (D, CA-6)',
#  'Cory A. Booker (D, NJ)',
#  'Brian Babin (R, TX-36)',
#  'Donald S. Beyer, Jr. (D, VA-8)',
#  'Mike Bost (R, IL-12)',
#  'Brendan F. Boyle (D, PA-2)',
#  'Don Bacon (R, NE-2)',
#  'Jim Banks (R, IN)',
#  'Nanette Diaz Barragán (D, CA-44)',
#  'Jack Bergman (R, MI-1)',
#  'Andy Biggs (R, AZ-5)',
#  'Lisa Blunt Rochester (D, DE)',
#  'Ted Budd (R, NC)',
#  'Troy Balderson (R, OH-12)',
#  'James R. Baird (R, IN-4)',
#  'Tim Burchett (R, TN-2)',
#  'Shontel M. Brown (D, OH-11)',
#  'Aaron Bean (R, FL-4)',
#  'Nikki Budzinski (D, IL-13)',
#  'Eric Burlison (R, MO-7)',
#  'Josh Brecheen (R, OK-2)',
#  'Becca Balint (D, VT-1)',
#  'Katie Boyd Britt (R, AL)',
#  'Tom Barrett (R, MI-7)',
#  'Michael Baumgartner (R, WA-5)',
#  'Nicholas J. Begich III (R, AK-1)',
#  'Wesley Bell (D, MO-1)',
#  'Sheri Biggs (R, SC-3)',
#  'Janelle S. Bynum (D, OR-5)',
#  'Robert P. Bresnahan, Jr. (R, PA-8)',
#  'Ken Calvert (R, CA-41)',
#  'Maria Cantwell (D, WA)',
#  'James E. Clyburn (D, SC-6)',
#  'Mike Crapo (R, ID)',
#  'Susan M. Collins (R, ME)',
#  'Kat Cammack (R, FL-3)',
#  'Shelley Moore Capito (R, WV)',
#  'John R. Carter (R, TX-31)',
#  'Tom Cole (R, OK-4)',
#  'Ed Case (D, HI-1)',
#  'John Cornyn (R, TX)',
#  'Jim Costa (D, CA-21)',
#  'Emanuel Cleaver (D, MO-5)',
#  'Henry Cuellar (D, TX-28)',
#  'Kathy Castor (D, FL-14)',
#  'Yvette D. Clarke (D, NY-9)',
#  'Steve Cohen (D, TN-9)',
#  'Joe Courtney (D, CT-2)',
#  'André Carson (D, IN-7)',
#  'Bill Cassidy (R, LA)',
#  'Gerald E. Connolly (D, VA-11)',
#  'Judy Chu (D, CA-28)',
#  'Eric A. "Rick" Crawford (R, AR-1)',
#  'Christopher A. Coons (D, DE)',
#  'Joaquin Castro (D, TX-20)',
#  'Tom Cotton (R, AR)',
#  'Kevin Cramer (R, ND)',
#  'Ted Cruz (R, TX)',
#  'Katherine M. Clark (D, MA-5)',
#  'Earl L. "Buddy" Carter (R, GA-1)',
#  'James Comer (R, KY-1)',
#  'J. Luis Correa (D, CA-46)',
#  'Salud O. Carbajal (D, CA-24)',
#  'Catherine Cortez Masto (D, NV)',
#  'John R. Curtis (R, UT)',
#  'Michael Cloud (R, TX-27)',
#  'Andrew S. Clyde (R, GA-9)',
#  'Sean Casten (D, IL-6)',
#  'Ben Cline (R, VA-6)',
#  'Angie Craig (D, MN-2)',
#  'Dan Crenshaw (R, TX-2)',
#  'Jason Crow (D, CO-6)',
#  'Gilbert Ray Cisneros, Jr. (D, CA-31)',
#  'Troy A. Carter (D, LA-2)',
#  'Mike Carey (R, OH-15)',
#  'Sheila Cherfilus-McCormick (D, FL-20)',
#  'Mike Collins (R, GA-10)',
#  'Jasmine Crockett (D, TX-30)',
#  'Greg Casar (D, TX-35)',
#  'Elijah Crane (R, AZ-2)',
#  'Juan Ciscomani (R, AZ-6)',
#  'Herbert C. Conaway, Jr. (D, NJ-3)',
#  'Jeff Crank (R, CO-5)',
#  'Byron Donalds (R, FL-19)',
#  'Danny K. Davis (D, IL-7)',
#  'Diana DeGette (D, CO-1)',
#  'Rosa L. DeLauro (D, CT-3)',
#  'Donald G. Davis (D, NC-1)',
#  'Lloyd Doggett (D, TX-37)',
#  'Christopher R. Deluzio (D, PA-17)',
#  'Richard J. Durbin (D, IL)',
#  'Monica De La Cruz (R, TX-15)',
#  'Mario Diaz-Balart (R, FL-26)',
#  'Scott DesJarlais (R, TN-4)',
#  'Suzan K. DelBene (D, WA-1)',
#  'Steve Daines (R, MT)',
#  'Tammy Duckworth (D, IL)',
#  'Mark DeSaulnier (D, CA-10)',
#  'Debbie Dingell (D, MI-6)',
#  'Warren Davidson (R, OH-8)',
#  'Neal P. Dunn (R, FL-2)',
#  'Sharice Davids (D, KS-3)',
#  'Madeleine Dean (D, PA-4)',
#  'Troy Downing (R, MT-2)',
#  'Maxine Dexter (D, OR-3)',
#  'Jake Ellzey (R, TX-6)',
#  'Mike Ezell (R, MS-4)',
#  'Chuck Edwards (R, NC-11)',
#  'Tom Emmer (R, MN-6)',
#  'Joni Ernst (R, IA)',
#  'Dwight Evans (D, PA-3)',
#  'Adriano Espaillat (D, NY-13)',
#  'Ron Estes (R, KS-4)',
#  'Veronica Escobar (D, TX-16)',
#  'Gabe Evans (R, CO-8)',
#  'Sarah Elfreth (D, MD-3)',
#  'Cleo Fields (D, LA-6)',
#  'Pat Fallon (R, TX-4)',
#  'Randy Feenstra (R, IA-4)',
#  'Virginia Foxx (R, NC-5)',
#  'Bill Foster (D, IL-11)',
#  'Charles J. "Chuck" Fleischmann (R, TN-3)',
#  'Lois Frankel (D, FL-22)',
#  'Deb Fischer (R, NE)',
#  'Brian K. Fitzpatrick (R, PA-1)',
#  'Lizzie Fletcher (D, TX-7)',
#  'Russ Fulcher (R, ID-1)',
#  'Michelle Fischbach (R, MN-7)',
#  'Scott Fitzgerald (R, WI-5)',
#  'Scott Franklin (R, FL-18)',
#  'Mike Flood (R, NE-1)',
#  'Brad Finstad (R, MN-1)',
#  'Maxwell Frost (D, FL-10)',
#  'Valerie P. Foushee (D, NC-4)',
#  'Russell Fry (R, SC-7)',
#  'John Fetterman (D, PA)',
#  'Vince Fong (R, CA-20)',
#  'Shomari Figures (D, AL-2)',
#  'Julie Fedorchak (R, ND-1)',
#  'Laura Friedman (D, CA-30)',
#  'Randy Fine (R, FL-6)',
#  'Lindsey Graham (R, SC)',
#  'Chuck Grassley (R, IA)',
#  'Sam Graves (R, MO-6)',
#  'Raúl M. Grijalva (D, AZ-7)',
#  'Al Green (D, TX-9)',
#  'Kirsten E. Gillibrand (D, NY)',
#  'Brett Guthrie (R, KY-2)',
#  'John Garamendi (D, CA-8)',
#  'Paul A. Gosar (R, AZ-9)',
#  'H. Morgan Griffith (R, VA-9)',
#  'Ruben Gallego (D, AZ)',
#  'Glenn Grothman (R, WI-6)',
#  'Vicente Gonzalez (D, TX-34)',
#  'Josh Gottheimer (D, NJ-5)',
#  'Jimmy Gomez (D, CA-34)',
#  'Jesús G. "Chuy" García (D, IL-4)',
#  'Sylvia R. Garcia (D, TX-29)',
#  'Lance Gooden (R, TX-5)',
#  'Mark E. Green (R, TN-7)',
#  'Michael Guest (R, MS-3)',
#  'Jared F. Golden (D, ME-2)',
#  'Carlos A. Gimenez (R, FL-28)',
#  'Tony Gonzales (R, TX-23)',
#  'Marjorie Taylor Greene (R, GA-14)',
#  'Andrew R. Garbarino (R, NY-2)',
#  'Robert Garcia (D, CA-42)',
#  'Daniel S. Goldman (D, NY-10)',
#  'Marie Gluesenkamp Perez (D, WA-3)',
#  'Craig A. Goldman (R, TX-12)',
#  'Laura Gillen (D, NY-4)',
#  'Brandon Gill (R, TX-26)',
#  'Maggie Goodlander (D, NH-2)',
#  'Adam Gray (D, CA-13)',
#  'John W. Hickenlooper (D, CO)',
#  'Bill Hagerty (R, TN)',
#  'Steny H. Hoyer (D, MD-5)',
#  'Mazie K. Hirono (D, HI)',
#  'Martin Heinrich (D, NM)',
#  'James A. Himes (D, CT-4)',
#  'Andy Harris (R, MD-1)',
#  'Bill Huizenga (R, MI-4)',
#  'John Hoeven (R, ND)',
#  'Steven Horsford (D, NV-4)',
#  'Richard Hudson (R, NC-9)',
#  'Jared Huffman (D, CA-2)',
#  'J. French Hill (R, AR-2)',
#  'Margaret Wood Hassan (D, NH)',
#  'Clay Higgins (R, LA-3)',
#  'Cindy Hyde-Smith (R, MS)',
#  'Jahana Hayes (D, CT-5)',
#  'Kevin Hern (R, OK-1)',
#  'Chrissy Houlahan (D, PA-6)',
#  'Diana Harshbarger (R, TN-1)',
#  'Josh Hawley (R, MO)',
#  'Josh Harder (D, CA-9)',
#  'Ashley Hinson (R, IA-2)',
#  'Erin Houchin (R, IN-9)',
#  'Val T. Hoyle (D, OR-4)',
#  'Wesley Hunt (R, TX-38)',
#  'Harriet M. Hageman (R, WY-1)',
#  'Abraham J. Hamadeh (R, AZ-8)',
#  'Mike Haridopolos (R, FL-8)',
#  'Jeff Hurd (R, CO-3)',
#  'Pat Harrigan (R, NC-10)',
#  'Mark Harris (R, NC-8)',
#  'Pablo José Hernández (D, PR)',
#  'Jon Husted (R, OH)',
#  'Darrell Issa (R, CA-48)',
#  'Glenn Ivey (D, MD-4)',
#  'Henry C. "Hank" Johnson, Jr. (D, GA-4)',
#  'Jim Jordan (R, OH-4)',
#  'Ron Johnson (R, WI)',
#  'Hakeem S. Jeffries (D, NY-8)',
#  'David P. Joyce (R, OH-14)',
#  'Pramila Jayapal (D, WA-7)',
#  'Mike Johnson (R, LA-4)',
#  'Dusty Johnson (R, SD-1)',
#  'John Joyce (R, PA-13)',
#  'Ronny Jackson (R, TX-13)',
#  'Sara Jacobs (D, CA-51)',
#  'John James (R, MI-10)',
#  'Jonathan L. Jackson (D, IL-1)',
#  'Julie Johnson (D, TX-32)',
#  'Brian Jack (R, GA-3)',
#  'James C. Justice (R, WV)',
#  'Marcy Kaptur (D, OH-9)',
#  'Amy Klobuchar (D, MN)',
#  'William R. Keating (D, MA-9)',
#  'Mike Kelly (R, PA-16)',
#  'Mark Kelly (D, AZ)',
#  'Angus S. King Jr. (I, ME)',
#  'Tim Kaine (D, VA)',
#  'Robin L. Kelly (D, IL-2)',
#  'Trent Kelly (R, MS-1)',
#  'Ro Khanna (D, CA-17)',
#  'Raja Krishnamoorthi (D, IL-8)',
#  'David Kustoff (R, TN-8)',
#  'John Kennedy (R, LA)',
#  'Andy Kim (D, NJ)',
#  'Young Kim (R, CA-40)',
#  'Thomas H. Kean, Jr. (R, NJ-7)',
#  'Jennifer A. Kiggans (R, VA-2)',
#  'Sydney Kamlager-Dove (D, CA-37)',
#  'Kevin Kiley (R, CA-3)',
#  'Timothy M. Kennedy (D, NY-26)',
#  'Mike Kennedy (R, UT-3)',
#  'Kimberlyn King-Hinds (R, MP)',
#  'Brad Knott (R, NC-13)',
#  'Teresa Leger Fernandez (D, NM-3)',
#  'Zoe Lofgren (D, CA-18)',
#  'Frank D. Lucas (R, OK-3)',
#  'John B. Larson (D, CT-1)',
#  'Rick Larsen (D, WA-2)',
#  'Stephen F. Lynch (D, MA-8)',
#  'Robert E. Latta (R, OH-5)',
#  'Ben Ray Luján (D, NM)',
#  'Cynthia M. Lummis (R, WY)',
#  'James Lankford (R, OK)',
#  'Mike Lee (R, UT)',
#  'Doug LaMalfa (R, CA-1)',
#  'Ted Lieu (D, CA-36)',
#  'Barry Loudermilk (R, GA-11)',
#  'Darin LaHood (R, IL-16)',
#  'Susie Lee (D, NV-3)',
#  'Mike Levin (D, CA-49)',
#  'Julia Letlow (R, LA-5)',
#  'Anna Paulina Luna (R, FL-13)',
#  'Laurel M. Lee (R, FL-15)',
#  'Nick LaLota (R, NY-1)',
#  'Michael Lawler (R, NY-17)',
#  'Nicholas A. Langworthy (R, NY-23)',
#  'Greg Landsman (D, OH-1)',
#  'Summer L. Lee (D, PA-12)',
#  'Morgan Luttrell (R, TX-8)',
#  'George Latimer (D, NY-16)',
#  'Sam T. Liccardo (D, CA-16)',
#  'Edward J. Markey (D, MA)',
#  'Nancy Mace (R, SC-1)',
#  'James P. McGovern (D, MA-2)',
#  'Nicole Malliotakis (R, NY-11)',
#  'Mitch McConnell (R, KY)',
#  'Kweisi Mfume (D, MD-7)',
#  'Tracey Mann (R, KS-1)',
#  'Jerry Moran (R, KS)',
#  'Patty Murray (D, WA)',
#  'Lisa C. McClain (R, MI-9)',
#  'Gregory W. Meeks (D, NY-5)',
#  'Betty McCollum (D, MN-4)',
#  'Lisa Murkowski (R, AK)',
#  'Michael T. McCaul (R, TX-10)',
#  'Gwen Moore (D, WI-4)',
#  'Doris O. Matsui (D, CA-7)',
#  'Christopher Murphy (D, CT)',
#  'Jeff Merkley (D, OR)',
#  'Tom McClintock (R, CA-5)',
#  'Thomas Massie (R, KY-4)',
#  'Grace Meng (D, NY-6)',
#  'Markwayne Mullin (R, OK)',
#  'John R. Moolenaar (R, MI-2)',
#  'Seth Moulton (D, MA-6)',
#  'Roger Marshall (R, KS)',
#  'Brian J. Mast (R, FL-21)',
#  'Daniel Meuser (R, PA-9)',
#  'Carol D. Miller (R, WV-1)',
#  'Joseph D. Morelle (D, NY-25)',
#  'Lucy McBath (D, GA-6)',
#  'Gregory F. Murphy (R, NC-3)',
#  'Mary E. Miller (R, IL-15)',
#  'Barry Moore (R, AL-1)',
#  'Blake D. Moore (R, UT-1)',
#  'Frank J. Mrvan (D, IN-1)',
#  'Mariannette Miller-Meeks (R, IA-1)',
#  'Cory Mills (R, FL-7)',
#  'Jared Moskowitz (D, FL-23)',
#  'Richard McCormick (R, GA-7)',
#  'James C. Moylan (R, GU)',
#  'Morgan McGarvey (D, KY-3)',
#  'Max L. Miller (R, OH-7)',
#  'Seth Magaziner (D, RI-2)',
#  'Nathaniel Moran (R, TX-1)',
#  'Kevin Mullin (D, CA-15)',
#  'Robert Menendez (D, NJ-8)',
#  'Jennifer L. McClellan (D, VA-4)',
#  'Celeste Maloy (R, UT-2)',
#  'LaMonica McIver (D, NJ-10)',
#  'Ryan Mackenzie (R, PA-7)',
#  'John W. Mannion (D, NY-22)',
#  'April McClain Delaney (D, MD-6)',
#  'Mark B. Messmer (R, IN-8)',
#  'Kelly Morrison (D, MN-3)',
#  'Riley M. Moore (R, WV-2)',
#  'Tim Moore (R, NC-14)',
#  'Kristen McDonald Rivet (D, MI-8)',
#  'Sarah McBride (D, DE-1)',
#  'John J. McGuire III (R, VA-5)',
#  'Addison P. McDowell (R, NC-6)',
#  'Dave Min (D, CA-47)',
#  'Bernie Moreno (R, OH)',
#  'David McCormick (R, PA)',
#  'Ashley Moody (R, FL)',
#  'Jerrold Nadler (D, NY-12)',
#  'Richard E. Neal (D, MA-1)',
#  'Troy E. Nehls (R, TX-22)',
#  'Eleanor Holmes Norton (D, DC)',
#  'Donald Norcross (D, NJ-1)',
#  'Dan Newhouse (R, WA-4)',
#  'Ralph Norman (R, SC-5)',
#  'Joe Neguse (D, CO-2)',
#  'Zachary Nunn (R, IA-3)',
#  'Jay Obernolte (R, CA-23)',
#  'Burgess Owens (R, UT-4)',
#  'Alexandria Ocasio-Cortez (D, NY-14)',
#  'Ilhan Omar (D, MN-5)',
#  'Jon Ossoff (D, GA)',
#  'Andrew Ogles (R, TN-5)',
#  'Johnny Olszewski, Jr. (D, MD-2)',
#  'Robert F. Onder, Jr. (R, MO-3)',
#  'Frank Pallone, Jr. (D, NJ-6)',
#  'August Pfluger (R, TX-11)',
#  'Alex Padilla (D, CA)',
#  'Nancy Pelosi (D, CA-11)',
#  'Gary C. Peters (D, MI)',
#  'Chellie Pingree (D, ME-1)',
#  'Rand Paul (R, KY)',
#  'Scott Perry (R, PA-10)',
#  'Mark Pocan (D, WI-2)',
#  'Scott H. Peters (D, CA-50)',
#  'Gary J. Palmer (R, AL-6)',
#  'Stacey E. Plaskett (D, VI)',
#  'Jimmy Panetta (D, CA-19)',
#  'Chris Pappas (D, NH-1)',
#  'Ayanna Pressley (D, MA-7)',
#  'Brittany Pettersen (D, CO-7)',
#  'Nellie Pou (D, NJ-9)',
#  'Jimmy Patronis (R, FL-1)',
#  'Mike Quigley (D, IL-5)',
#  'Jack Reed (D, RI)',
#  'Deborah K. Ross (D, NC-2)',
#  'Harold Rogers (R, KY-5)',
#  'Mike Rogers (R, AL-3)',
#  'Patrick Ryan (D, NY-18)',
#  'James E. Risch (R, ID)',
#  'Marco Rubio (R, FL)',
#  'Raul Ruiz (D, CA-25)',
#  'Aumua Amata Coleman Radewagen (R, AS)',
#  'David Rouzer (R, NC-7)',
#  'Mike Rounds (R, SD)',
#  'Jamie Raskin (D, MD-8)',
#  'Jacky Rosen (D, NV)',
#  'John H. Rutherford (R, FL-5)',
#  'Guy Reschenthaler (R, PA-14)',
#  'John W. Rose (R, TN-6)',
#  'Chip Roy (R, TX-21)',
#  'Delia C. Ramirez (D, IL-3)',
#  'Pete Ricketts (R, NE)',
#  'Michael A. Rulli (R, OH-6)',
#  'Luz M. Rivas (D, CA-29)',
#  'Emily Randall (D, WA-6)',
#  'Josh Riley (D, NY-19)',
#  'Bernard Sanders (I, VT)',
#  'Charles E. Schumer (D, NY)',
#  'Maria Elvira Salazar (R, FL-27)',
#  'Robert C. "Bobby" Scott (D, VA-3)',
#  'Pete Sessions (R, TX-17)',
#  'Brad Sherman (D, CA-32)',
#  'Adam Smith (D, WA-9)',
#  'Christopher H. Smith (R, NJ-4)',
#  'Victoria Spartz (R, IN-5)',
#  'Janice D. Schakowsky (D, IL-9)',
#  'Michael K. Simpson (R, ID-2)',
#  'Adam B. Schiff (D, CA)',
#  'Linda T. Sánchez (D, CA-38)',
#  'David Scott (D, GA-13)',
#  'Marilyn Strickland (D, WA-10)',
#  'Adrian Smith (R, NE-3)',
#  'Steve Scalise (R, LA-1)',
#  'Jeanne Shaheen (D, NH)',
#  'David Schweikert (R, AZ-1)',
#  'Tim Scott (R, SC)',
#  'Terri A. Sewell (D, AL-7)',
#  'Marlin A. Stutzman (R, IN-3)',
#  'Austin Scott (R, GA-8)',
#  'Bradley Scott Schneider (D, IL-10)',
#  'Eric Swalwell (D, CA-14)',
#  'Brian Schatz (D, HI)',
#  'Jason Smith (R, MO-8)',
#  'Elise M. Stefanik (R, NY-21)',
#  'Dan Sullivan (R, AK)',
#  'Lloyd Smucker (R, PA-11)',
#  'Darren Soto (D, FL-9)',
#  'Thomas R. Suozzi (D, NY-3)',
#  'Tina Smith (D, MN)',
#  'Mary Gay Scanlon (D, PA-5)',
#  'Mikie Sherrill (D, NJ-11)',
#  'Elissa Slotkin (D, MI)',
#  'Greg Stanton (D, AZ-4)',
#  'Pete Stauber (R, MN-8)',
#  'Bryan Steil (R, WI-1)',
#  'W. Gregory Steube (R, FL-17)',
#  'Haley M. Stevens (D, MI-11)',
#  'Kim Schrier (D, WA-8)',
#  'Rick Scott (R, FL)',
#  'Melanie A. Stansbury (D, NM-1)',
#  'Dale W. Strong (R, AL-5)',
#  'Hillary J. Scholten (D, MI-3)',
#  'Emilia Strong Sykes (D, OH-13)',
#  'Keith Self (R, TX-3)',
#  'Eric Sorensen (D, IL-17)',
#  'Andrea Salinas (D, OR-6)',
#  'Eric Schmitt (R, MO)',
#  'Derek Schmidt (R, KS-2)',
#  'Jefferson Shreve (R, IN-6)',
#  'Suhas Subramanyam (D, VA-10)',
#  'Lateefah Simon (D, CA-12)',
#  'Tim Sheehy (R, MT)',
#  'Thomas P. Tiffany (R, WI-7)',
#  'Bennie G. Thompson (D, MS-2)',
#  'John Thune (R, SD)',
#  'Tommy Tuberville (R, AL)',
#  'Mike Thompson (D, CA-4)',
#  'Michael R. Turner (R, OH-10)',
#  'Glenn Thompson (R, PA-15)',
#  'Dina Titus (D, NV-1)',
#  'Paul Tonko (D, NY-20)',
#  'Mark Takano (D, CA-39)',
#  'Norma J. Torres (D, CA-35)',
#  'Thom Tillis (R, NC)',
#  'Claudia Tenney (R, NY-24)',
#  'William R. Timmons IV (R, SC-4)',
#  'Rashida Tlaib (D, MI-12)',
#  'Lori Trahan (D, MA-3)',
#  'Ritchie Torres (D, NY-15)',
#  'Jill N. Tokuda (D, HI-2)',
#  'Shri Thanedar (D, MI-13)',
#  'Sylvester Turner (D, TX-18)',
#  'David J. Taylor (R, OH-2)',
#  'Derek Tran (D, CA-45)',
#  'Lauren Underwood (D, IL-14)',
#  'Nydia M. Velázquez (D, NY-7)',
#  'Chris Van Hollen (D, MD)',
#  'David G. Valadao (R, CA-22)',
#  'Juan Vargas (D, CA-52)',
#  'Marc A. Veasey (D, TX-33)',
#  'Jefferson Van Drew (R, NJ-2)',
#  'Beth Van Duyne (R, TX-24)',
#  'Derrick Van Orden (R, WI-3)',
#  'Gabe Vasquez (D, NM-2)',
#  'J. D. Vance (R, OH)',
#  'Eugene Simon Vindman (D, VA-7)',
#  'Maxine Waters (D, CA-43)',
#  'Roger F. Wicker (R, MS)',
#  'Ron Wyden (D, OR)',
#  'Nikema Williams (D, GA-5)',
#  'Raphael G. Warnock (D, GA)',
#  'Joe Wilson (R, SC-2)',
#  'Debbie Wasserman Schultz (D, FL-25)',
#  'Tim Walberg (R, MI-5)',
#  'Peter Welch (D, VT)',
#  'Sheldon Whitehouse (D, RI)',
#  'Robert J. Wittman (R, VA-1)',
#  'Mark R. Warner (D, VA)',
#  'Daniel Webster (R, FL-11)',
#  'Frederica S. Wilson (D, FL-24)',
#  'Steve Womack (R, AR-3)',
#  'Ann Wagner (R, MO-2)',
#  'Randy K. Weber, Sr. (R, TX-14)',
#  'Roger Williams (R, TX-25)',
#  'Elizabeth Warren (D, MA)',
#  'Bruce Westerman (R, AR-4)',
#  'Bonnie Watson Coleman (D, NJ-12)',
#  'Michael Waltz (R, FL-6)',
#  'Tony Wied (R, WI-8)',
#  'George Whitesides (D, CA-27)',
#  'James R. Walkinshaw (D, VA-11)',
#  'Todd Young (R, IN)',
#  'Rudy Yakym III (R, IN-2)',
#  'Ryan K. Zinke (R, MT-1)']

# %%
dropdown_options = [{'label': y, 'value': x} for x, y in zip(data['bioguide_id'], display_name)]

# %%
dropdown_options
# Out:
# [{'label': 'Robert B. Aderholt (R, AL-4)', 'value': 'A000055'},
#  {'label': 'Jake Auchincloss (D, MA-4)', 'value': 'A000148'},
#  {'label': 'Mark E. Amodei (R, NV-2)', 'value': 'A000369'},
#  {'label': 'Alma S. Adams (D, NC-12)', 'value': 'A000370'},
#  {'label': 'Pete Aguilar (D, CA-33)', 'value': 'A000371'},
#  {'label': 'Rick W. Allen (R, GA-12)', 'value': 'A000372'},
#  {'label': 'Jodey C. Arrington (R, TX-19)', 'value': 'A000375'},
#  {'label': 'Mark Alford (R, MO-4)', 'value': 'A000379'},
#  {'label': 'Gabe Amo (D, RI-1)', 'value': 'A000380'},
#  {'label': 'Yassamin Ansari (D, AZ-3)', 'value': 'A000381'},
#  {'label': 'Angela D. Alsobrooks (D, MD)', 'value': 'A000382'},
#  {'label': 'Sanford D. Bishop, Jr. (D, GA-2)', 'value': 'B000490'},
#  {'label': 'Cliff Bentz (R, OR-2)', 'value': 'B000668'},
#  {'label': 'Stephanie I. Bice (R, OK-5)', 'value': 'B000740'},
#  {'label': 'Lauren Boebert (R, CO-4)', 'value': 'B000825'},
#  {'label': 'Tammy Baldwin (D, WI)', 'value': 'B001230'},
#  {'label': 'John Boozman (R, AR)', 'value': 'B001236'},
#  {'label': 'Marsha Blackburn (R, TN)', 'value': 'B001243'},
#  {'label': 'Gus M. Bilirakis (R, FL-12)', 'value': 'B001257'},
#  {'label': 'Vern Buchanan (R, FL-16)', 'value': 'B001260'},
#  {'label': 'John Barrasso (R, WY)', 'value': 'B001261'},
#  {'label': 'Michael F. Bennet (D, CO)', 'value': 'B001267'},
#  {'label': 'Richard Blumenthal (D, CT)', 'value': 'B001277'},
#  {'label': 'Suzanne Bonamici (D, OR-1)', 'value': 'B001278'},
#  {'label': 'Joyce Beatty (D, OH-3)', 'value': 'B001281'},
#  {'label': 'Andy Barr (R, KY-6)', 'value': 'B001282'},
#  {'label': 'Julia Brownley (D, CA-26)', 'value': 'B001285'},
#  {'label': 'Ami Bera (D, CA-6)', 'value': 'B001287'},
#  {'label': 'Cory A. Booker (D, NJ)', 'value': 'B001288'},
#  {'label': 'Brian Babin (R, TX-36)', 'value': 'B001291'},
#  {'label': 'Donald S. Beyer, Jr. (D, VA-8)', 'value': 'B001292'},
#  {'label': 'Mike Bost (R, IL-12)', 'value': 'B001295'},
#  {'label': 'Brendan F. Boyle (D, PA-2)', 'value': 'B001296'},
#  {'label': 'Don Bacon (R, NE-2)', 'value': 'B001298'},
#  {'label': 'Jim Banks (R, IN)', 'value': 'B001299'},
#  {'label': 'Nanette Diaz Barragán (D, CA-44)', 'value': 'B001300'},
#  {'label': 'Jack Bergman (R, MI-1)', 'value': 'B001301'},
#  {'label': 'Andy Biggs (R, AZ-5)', 'value': 'B001302'},
#  {'label': 'Lisa Blunt Rochester (D, DE)', 'value': 'B001303'},
#  {'label': 'Ted Budd (R, NC)', 'value': 'B001305'},
#  {'label': 'Troy Balderson (R, OH-12)', 'value': 'B001306'},
#  {'label': 'James R. Baird (R, IN-4)', 'value': 'B001307'},
#  {'label': 'Tim Burchett (R, TN-2)', 'value': 'B001309'},
#  {'label': 'Shontel M. Brown (D, OH-11)', 'value': 'B001313'},
#  {'label': 'Aaron Bean (R, FL-4)', 'value': 'B001314'},
#  {'label': 'Nikki Budzinski (D, IL-13)', 'value': 'B001315'},
#  {'label': 'Eric Burlison (R, MO-7)', 'value': 'B001316'},
#  {'label': 'Josh Brecheen (R, OK-2)', 'value': 'B001317'},
#  {'label': 'Becca Balint (D, VT-1)', 'value': 'B001318'},
#  {'label': 'Katie Boyd Britt (R, AL)', 'value': 'B001319'},
#  {'label': 'Tom Barrett (R, MI-7)', 'value': 'B001321'},
#  {'label': 'Michael Baumgartner (R, WA-5)', 'value': 'B001322'},
#  {'label': 'Nicholas J. Begich III (R, AK-1)', 'value': 'B001323'},
#  {'label': 'Wesley Bell (D, MO-1)', 'value': 'B001324'},
#  {'label': 'Sheri Biggs (R, SC-3)', 'value': 'B001325'},
#  {'label': 'Janelle S. Bynum (D, OR-5)', 'value': 'B001326'},
#  {'label': 'Robert P. Bresnahan, Jr. (R, PA-8)', 'value': 'B001327'},
#  {'label': 'Ken Calvert (R, CA-41)', 'value': 'C000059'},
#  {'label': 'Maria Cantwell (D, WA)', 'value': 'C000127'},
#  {'label': 'James E. Clyburn (D, SC-6)', 'value': 'C000537'},
#  {'label': 'Mike Crapo (R, ID)', 'value': 'C000880'},
#  {'label': 'Susan M. Collins (R, ME)', 'value': 'C001035'},
#  {'label': 'Kat Cammack (R, FL-3)', 'value': 'C001039'},
#  {'label': 'Shelley Moore Capito (R, WV)', 'value': 'C001047'},
#  {'label': 'John R. Carter (R, TX-31)', 'value': 'C001051'},
#  {'label': 'Tom Cole (R, OK-4)', 'value': 'C001053'},
#  {'label': 'Ed Case (D, HI-1)', 'value': 'C001055'},
#  {'label': 'John Cornyn (R, TX)', 'value': 'C001056'},
#  {'label': 'Jim Costa (D, CA-21)', 'value': 'C001059'},
#  {'label': 'Emanuel Cleaver (D, MO-5)', 'value': 'C001061'},
#  {'label': 'Henry Cuellar (D, TX-28)', 'value': 'C001063'},
#  {'label': 'Kathy Castor (D, FL-14)', 'value': 'C001066'},
#  {'label': 'Yvette D. Clarke (D, NY-9)', 'value': 'C001067'},
#  {'label': 'Steve Cohen (D, TN-9)', 'value': 'C001068'},
#  {'label': 'Joe Courtney (D, CT-2)', 'value': 'C001069'},
#  {'label': 'André Carson (D, IN-7)', 'value': 'C001072'},
#  {'label': 'Bill Cassidy (R, LA)', 'value': 'C001075'},
#  {'label': 'Gerald E. Connolly (D, VA-11)', 'value': 'C001078'},
#  {'label': 'Judy Chu (D, CA-28)', 'value': 'C001080'},
#  {'label': 'Eric A. "Rick" Crawford (R, AR-1)', 'value': 'C001087'},
#  {'label': 'Christopher A. Coons (D, DE)', 'value': 'C001088'},
#  {'label': 'Joaquin Castro (D, TX-20)', 'value': 'C001091'},
#  {'label': 'Tom Cotton (R, AR)', 'value': 'C001095'},
#  {'label': 'Kevin Cramer (R, ND)', 'value': 'C001096'},
#  {'label': 'Ted Cruz (R, TX)', 'value': 'C001098'},
#  {'label': 'Katherine M. Clark (D, MA-5)', 'value': 'C001101'},
#  {'label': 'Earl L. "Buddy" Carter (R, GA-1)', 'value': 'C001103'},
#  {'label': 'James Comer (R, KY-1)', 'value': 'C001108'},
#  {'label': 'J. Luis Correa (D, CA-46)', 'value': 'C001110'},
#  {'label': 'Salud O. Carbajal (D, CA-24)', 'value': 'C001112'},
#  {'label': 'Catherine Cortez Masto (D, NV)', 'value': 'C001113'},
#  {'label': 'John R. Curtis (R, UT)', 'value': 'C001114'},
#  {'label': 'Michael Cloud (R, TX-27)', 'value': 'C001115'},
#  {'label': 'Andrew S. Clyde (R, GA-9)', 'value': 'C001116'},
#  {'label': 'Sean Casten (D, IL-6)', 'value': 'C001117'},
#  {'label': 'Ben Cline (R, VA-6)', 'value': 'C001118'},
#  {'label': 'Angie Craig (D, MN-2)', 'value': 'C001119'},
#  {'label': 'Dan Crenshaw (R, TX-2)', 'value': 'C001120'},
#  {'label': 'Jason Crow (D, CO-6)', 'value': 'C001121'},
#  {'label': 'Gilbert Ray Cisneros, Jr. (D, CA-31)', 'value': 'C001123'},
#  {'label': 'Troy A. Carter (D, LA-2)', 'value': 'C001125'},
#  {'label': 'Mike Carey (R, OH-15)', 'value': 'C001126'},
#  {'label': 'Sheila Cherfilus-McCormick (D, FL-20)', 'value': 'C001127'},
#  {'label': 'Mike Collins (R, GA-10)', 'value': 'C001129'},
#  {'label': 'Jasmine Crockett (D, TX-30)', 'value': 'C001130'},
#  {'label': 'Greg Casar (D, TX-35)', 'value': 'C001131'},
#  {'label': 'Elijah Crane (R, AZ-2)', 'value': 'C001132'},
#  {'label': 'Juan Ciscomani (R, AZ-6)', 'value': 'C001133'},
#  {'label': 'Herbert C. Conaway, Jr. (D, NJ-3)', 'value': 'C001136'},
#  {'label': 'Jeff Crank (R, CO-5)', 'value': 'C001137'},
#  {'label': 'Byron Donalds (R, FL-19)', 'value': 'D000032'},
#  {'label': 'Danny K. Davis (D, IL-7)', 'value': 'D000096'},
#  {'label': 'Diana DeGette (D, CO-1)', 'value': 'D000197'},
#  {'label': 'Rosa L. DeLauro (D, CT-3)', 'value': 'D000216'},
#  {'label': 'Donald G. Davis (D, NC-1)', 'value': 'D000230'},
#  {'label': 'Lloyd Doggett (D, TX-37)', 'value': 'D000399'},
#  {'label': 'Christopher R. Deluzio (D, PA-17)', 'value': 'D000530'},
#  {'label': 'Richard J. Durbin (D, IL)', 'value': 'D000563'},
#  {'label': 'Monica De La Cruz (R, TX-15)', 'value': 'D000594'},
#  {'label': 'Mario Diaz-Balart (R, FL-26)', 'value': 'D000600'},
#  {'label': 'Scott DesJarlais (R, TN-4)', 'value': 'D000616'},
#  {'label': 'Suzan K. DelBene (D, WA-1)', 'value': 'D000617'},
#  {'label': 'Steve Daines (R, MT)', 'value': 'D000618'},
#  {'label': 'Tammy Duckworth (D, IL)', 'value': 'D000622'},
#  {'label': 'Mark DeSaulnier (D, CA-10)', 'value': 'D000623'},
#  {'label': 'Debbie Dingell (D, MI-6)', 'value': 'D000624'},
#  {'label': 'Warren Davidson (R, OH-8)', 'value': 'D000626'},
#  {'label': 'Neal P. Dunn (R, FL-2)', 'value': 'D000628'},
#  {'label': 'Sharice Davids (D, KS-3)', 'value': 'D000629'},
#  {'label': 'Madeleine Dean (D, PA-4)', 'value': 'D000631'},
#  {'label': 'Troy Downing (R, MT-2)', 'value': 'D000634'},
#  {'label': 'Maxine Dexter (D, OR-3)', 'value': 'D000635'},
#  {'label': 'Jake Ellzey (R, TX-6)', 'value': 'E000071'},
#  {'label': 'Mike Ezell (R, MS-4)', 'value': 'E000235'},
#  {'label': 'Chuck Edwards (R, NC-11)', 'value': 'E000246'},
#  {'label': 'Tom Emmer (R, MN-6)', 'value': 'E000294'},
#  {'label': 'Joni Ernst (R, IA)', 'value': 'E000295'},
#  {'label': 'Dwight Evans (D, PA-3)', 'value': 'E000296'},
#  {'label': 'Adriano Espaillat (D, NY-13)', 'value': 'E000297'},
#  {'label': 'Ron Estes (R, KS-4)', 'value': 'E000298'},
#  {'label': 'Veronica Escobar (D, TX-16)', 'value': 'E000299'},
#  {'label': 'Gabe Evans (R, CO-8)', 'value': 'E000300'},
#  {'label': 'Sarah Elfreth (D, MD-3)', 'value': 'E000301'},
#  {'label': 'Cleo Fields (D, LA-6)', 'value': 'F000110'},
#  {'label': 'Pat Fallon (R, TX-4)', 'value': 'F000246'},
#  {'label': 'Randy Feenstra (R, IA-4)', 'value': 'F000446'},
#  {'label': 'Virginia Foxx (R, NC-5)', 'value': 'F000450'},
#  {'label': 'Bill Foster (D, IL-11)', 'value': 'F000454'},
#  {'label': 'Charles J. "Chuck" Fleischmann (R, TN-3)', 'value': 'F000459'},
#  {'label': 'Lois Frankel (D, FL-22)', 'value': 'F000462'},
#  {'label': 'Deb Fischer (R, NE)', 'value': 'F000463'},
#  {'label': 'Brian K. Fitzpatrick (R, PA-1)', 'value': 'F000466'},
#  {'label': 'Lizzie Fletcher (D, TX-7)', 'value': 'F000468'},
#  {'label': 'Russ Fulcher (R, ID-1)', 'value': 'F000469'},
#  {'label': 'Michelle Fischbach (R, MN-7)', 'value': 'F000470'},
#  {'label': 'Scott Fitzgerald (R, WI-5)', 'value': 'F000471'},
#  {'label': 'Scott Franklin (R, FL-18)', 'value': 'F000472'},
#  {'label': 'Mike Flood (R, NE-1)', 'value': 'F000474'},
#  {'label': 'Brad Finstad (R, MN-1)', 'value': 'F000475'},
#  {'label': 'Maxwell Frost (D, FL-10)', 'value': 'F000476'},
#  {'label': 'Valerie P. Foushee (D, NC-4)', 'value': 'F000477'},
#  {'label': 'Russell Fry (R, SC-7)', 'value': 'F000478'},
#  {'label': 'John Fetterman (D, PA)', 'value': 'F000479'},
#  {'label': 'Vince Fong (R, CA-20)', 'value': 'F000480'},
#  {'label': 'Shomari Figures (D, AL-2)', 'value': 'F000481'},
#  {'label': 'Julie Fedorchak (R, ND-1)', 'value': 'F000482'},
#  {'label': 'Laura Friedman (D, CA-30)', 'value': 'F000483'},
#  {'label': 'Randy Fine (R, FL-6)', 'value': 'F000484'},
#  {'label': 'Lindsey Graham (R, SC)', 'value': 'G000359'},
#  {'label': 'Chuck Grassley (R, IA)', 'value': 'G000386'},
#  {'label': 'Sam Graves (R, MO-6)', 'value': 'G000546'},
#  {'label': 'Raúl M. Grijalva (D, AZ-7)', 'value': 'G000551'},
#  {'label': 'Al Green (D, TX-9)', 'value': 'G000553'},
#  {'label': 'Kirsten E. Gillibrand (D, NY)', 'value': 'G000555'},
#  {'label': 'Brett Guthrie (R, KY-2)', 'value': 'G000558'},
#  {'label': 'John Garamendi (D, CA-8)', 'value': 'G000559'},
#  {'label': 'Paul A. Gosar (R, AZ-9)', 'value': 'G000565'},
#  {'label': 'H. Morgan Griffith (R, VA-9)', 'value': 'G000568'},
#  {'label': 'Ruben Gallego (D, AZ)', 'value': 'G000574'},
#  {'label': 'Glenn Grothman (R, WI-6)', 'value': 'G000576'},
#  {'label': 'Vicente Gonzalez (D, TX-34)', 'value': 'G000581'},
#  {'label': 'Josh Gottheimer (D, NJ-5)', 'value': 'G000583'},
#  {'label': 'Jimmy Gomez (D, CA-34)', 'value': 'G000585'},
#  {'label': 'Jesús G. "Chuy" García (D, IL-4)', 'value': 'G000586'},
#  {'label': 'Sylvia R. Garcia (D, TX-29)', 'value': 'G000587'},
#  {'label': 'Lance Gooden (R, TX-5)', 'value': 'G000589'},
#  {'label': 'Mark E. Green (R, TN-7)', 'value': 'G000590'},
#  {'label': 'Michael Guest (R, MS-3)', 'value': 'G000591'},
#  {'label': 'Jared F. Golden (D, ME-2)', 'value': 'G000592'},
#  {'label': 'Carlos A. Gimenez (R, FL-28)', 'value': 'G000593'},
#  {'label': 'Tony Gonzales (R, TX-23)', 'value': 'G000594'},
#  {'label': 'Marjorie Taylor Greene (R, GA-14)', 'value': 'G000596'},
#  {'label': 'Andrew R. Garbarino (R, NY-2)', 'value': 'G000597'},
#  {'label': 'Robert Garcia (D, CA-42)', 'value': 'G000598'},
#  {'label': 'Daniel S. Goldman (D, NY-10)', 'value': 'G000599'},
#  {'label': 'Marie Gluesenkamp Perez (D, WA-3)', 'value': 'G000600'},
#  {'label': 'Craig A. Goldman (R, TX-12)', 'value': 'G000601'},
#  {'label': 'Laura Gillen (D, NY-4)', 'value': 'G000602'},
#  {'label': 'Brandon Gill (R, TX-26)', 'value': 'G000603'},
#  {'label': 'Maggie Goodlander (D, NH-2)', 'value': 'G000604'},
#  {'label': 'Adam Gray (D, CA-13)', 'value': 'G000605'},
#  {'label': 'John W. Hickenlooper (D, CO)', 'value': 'H000273'},
#  {'label': 'Bill Hagerty (R, TN)', 'value': 'H000601'},
#  {'label': 'Steny H. Hoyer (D, MD-5)', 'value': 'H000874'},
#  {'label': 'Mazie K. Hirono (D, HI)', 'value': 'H001042'},
#  {'label': 'Martin Heinrich (D, NM)', 'value': 'H001046'},
#  {'label': 'James A. Himes (D, CT-4)', 'value': 'H001047'},
#  {'label': 'Andy Harris (R, MD-1)', 'value': 'H001052'},
#  {'label': 'Bill Huizenga (R, MI-4)', 'value': 'H001058'},
#  {'label': 'John Hoeven (R, ND)', 'value': 'H001061'},
#  {'label': 'Steven Horsford (D, NV-4)', 'value': 'H001066'},
#  {'label': 'Richard Hudson (R, NC-9)', 'value': 'H001067'},
#  {'label': 'Jared Huffman (D, CA-2)', 'value': 'H001068'},
#  {'label': 'J. French Hill (R, AR-2)', 'value': 'H001072'},
#  {'label': 'Margaret Wood Hassan (D, NH)', 'value': 'H001076'},
#  {'label': 'Clay Higgins (R, LA-3)', 'value': 'H001077'},
#  {'label': 'Cindy Hyde-Smith (R, MS)', 'value': 'H001079'},
#  {'label': 'Jahana Hayes (D, CT-5)', 'value': 'H001081'},
#  {'label': 'Kevin Hern (R, OK-1)', 'value': 'H001082'},
#  {'label': 'Chrissy Houlahan (D, PA-6)', 'value': 'H001085'},
#  {'label': 'Diana Harshbarger (R, TN-1)', 'value': 'H001086'},
#  {'label': 'Josh Hawley (R, MO)', 'value': 'H001089'},
#  {'label': 'Josh Harder (D, CA-9)', 'value': 'H001090'},
#  {'label': 'Ashley Hinson (R, IA-2)', 'value': 'H001091'},
#  {'label': 'Erin Houchin (R, IN-9)', 'value': 'H001093'},
#  {'label': 'Val T. Hoyle (D, OR-4)', 'value': 'H001094'},
#  {'label': 'Wesley Hunt (R, TX-38)', 'value': 'H001095'},
#  {'label': 'Harriet M. Hageman (R, WY-1)', 'value': 'H001096'},
#  {'label': 'Abraham J. Hamadeh (R, AZ-8)', 'value': 'H001098'},
#  {'label': 'Mike Haridopolos (R, FL-8)', 'value': 'H001099'},
#  {'label': 'Jeff Hurd (R, CO-3)', 'value': 'H001100'},
#  {'label': 'Pat Harrigan (R, NC-10)', 'value': 'H001101'},
#  {'label': 'Mark Harris (R, NC-8)', 'value': 'H001102'},
#  {'label': 'Pablo José Hernández (D, PR)', 'value': 'H001103'},
#  {'label': 'Jon Husted (R, OH)', 'value': 'H001104'},
#  {'label': 'Darrell Issa (R, CA-48)', 'value': 'I000056'},
#  {'label': 'Glenn Ivey (D, MD-4)', 'value': 'I000058'},
#  {'label': 'Henry C. "Hank" Johnson, Jr. (D, GA-4)', 'value': 'J000288'},
#  {'label': 'Jim Jordan (R, OH-4)', 'value': 'J000289'},
#  {'label': 'Ron Johnson (R, WI)', 'value': 'J000293'},
#  {'label': 'Hakeem S. Jeffries (D, NY-8)', 'value': 'J000294'},
#  {'label': 'David P. Joyce (R, OH-14)', 'value': 'J000295'},
#  {'label': 'Pramila Jayapal (D, WA-7)', 'value': 'J000298'},
#  {'label': 'Mike Johnson (R, LA-4)', 'value': 'J000299'},
#  {'label': 'Dusty Johnson (R, SD-1)', 'value': 'J000301'},
#  {'label': 'John Joyce (R, PA-13)', 'value': 'J000302'},
#  {'label': 'Ronny Jackson (R, TX-13)', 'value': 'J000304'},
#  {'label': 'Sara Jacobs (D, CA-51)', 'value': 'J000305'},
#  {'label': 'John James (R, MI-10)', 'value': 'J000307'},
#  {'label': 'Jonathan L. Jackson (D, IL-1)', 'value': 'J000309'},
#  {'label': 'Julie Johnson (D, TX-32)', 'value': 'J000310'},
#  {'label': 'Brian Jack (R, GA-3)', 'value': 'J000311'},
#  {'label': 'James C. Justice (R, WV)', 'value': 'J000312'},
#  {'label': 'Marcy Kaptur (D, OH-9)', 'value': 'K000009'},
#  {'label': 'Amy Klobuchar (D, MN)', 'value': 'K000367'},
#  {'label': 'William R. Keating (D, MA-9)', 'value': 'K000375'},
#  {'label': 'Mike Kelly (R, PA-16)', 'value': 'K000376'},
#  {'label': 'Mark Kelly (D, AZ)', 'value': 'K000377'},
#  {'label': 'Angus S. King Jr. (I, ME)', 'value': 'K000383'},
#  {'label': 'Tim Kaine (D, VA)', 'value': 'K000384'},
#  {'label': 'Robin L. Kelly (D, IL-2)', 'value': 'K000385'},
#  {'label': 'Trent Kelly (R, MS-1)', 'value': 'K000388'},
#  {'label': 'Ro Khanna (D, CA-17)', 'value': 'K000389'},
#  {'label': 'Raja Krishnamoorthi (D, IL-8)', 'value': 'K000391'},
#  {'label': 'David Kustoff (R, TN-8)', 'value': 'K000392'},
#  {'label': 'John Kennedy (R, LA)', 'value': 'K000393'},
#  {'label': 'Andy Kim (D, NJ)', 'value': 'K000394'},
#  {'label': 'Young Kim (R, CA-40)', 'value': 'K000397'},
#  {'label': 'Thomas H. Kean, Jr. (R, NJ-7)', 'value': 'K000398'},
#  {'label': 'Jennifer A. Kiggans (R, VA-2)', 'value': 'K000399'},
#  {'label': 'Sydney Kamlager-Dove (D, CA-37)', 'value': 'K000400'},
#  {'label': 'Kevin Kiley (R, CA-3)', 'value': 'K000401'},
#  {'label': 'Timothy M. Kennedy (D, NY-26)', 'value': 'K000402'},
#  {'label': 'Mike Kennedy (R, UT-3)', 'value': 'K000403'},
#  {'label': 'Kimberlyn King-Hinds (R, MP)', 'value': 'K000404'},
#  {'label': 'Brad Knott (R, NC-13)', 'value': 'K000405'},
#  {'label': 'Teresa Leger Fernandez (D, NM-3)', 'value': 'L000273'},
#  {'label': 'Zoe Lofgren (D, CA-18)', 'value': 'L000397'},
#  {'label': 'Frank D. Lucas (R, OK-3)', 'value': 'L000491'},
#  {'label': 'John B. Larson (D, CT-1)', 'value': 'L000557'},
#  {'label': 'Rick Larsen (D, WA-2)', 'value': 'L000560'},
#  {'label': 'Stephen F. Lynch (D, MA-8)', 'value': 'L000562'},
#  {'label': 'Robert E. Latta (R, OH-5)', 'value': 'L000566'},
#  {'label': 'Ben Ray Luján (D, NM)', 'value': 'L000570'},
#  {'label': 'Cynthia M. Lummis (R, WY)', 'value': 'L000571'},
#  {'label': 'James Lankford (R, OK)', 'value': 'L000575'},
#  {'label': 'Mike Lee (R, UT)', 'value': 'L000577'},
#  {'label': 'Doug LaMalfa (R, CA-1)', 'value': 'L000578'},
#  {'label': 'Ted Lieu (D, CA-36)', 'value': 'L000582'},
#  {'label': 'Barry Loudermilk (R, GA-11)', 'value': 'L000583'},
#  {'label': 'Darin LaHood (R, IL-16)', 'value': 'L000585'},
#  {'label': 'Susie Lee (D, NV-3)', 'value': 'L000590'},
#  {'label': 'Mike Levin (D, CA-49)', 'value': 'L000593'},
#  {'label': 'Julia Letlow (R, LA-5)', 'value': 'L000595'},
#  {'label': 'Anna Paulina Luna (R, FL-13)', 'value': 'L000596'},
#  {'label': 'Laurel M. Lee (R, FL-15)', 'value': 'L000597'},
#  {'label': 'Nick LaLota (R, NY-1)', 'value': 'L000598'},
#  {'label': 'Michael Lawler (R, NY-17)', 'value': 'L000599'},
#  {'label': 'Nicholas A. Langworthy (R, NY-23)', 'value': 'L000600'},
#  {'label': 'Greg Landsman (D, OH-1)', 'value': 'L000601'},
#  {'label': 'Summer L. Lee (D, PA-12)', 'value': 'L000602'},
#  {'label': 'Morgan Luttrell (R, TX-8)', 'value': 'L000603'},
#  {'label': 'George Latimer (D, NY-16)', 'value': 'L000606'},
#  {'label': 'Sam T. Liccardo (D, CA-16)', 'value': 'L000607'},
#  {'label': 'Edward J. Markey (D, MA)', 'value': 'M000133'},
#  {'label': 'Nancy Mace (R, SC-1)', 'value': 'M000194'},
#  {'label': 'James P. McGovern (D, MA-2)', 'value': 'M000312'},
#  {'label': 'Nicole Malliotakis (R, NY-11)', 'value': 'M000317'},
#  {'label': 'Mitch McConnell (R, KY)', 'value': 'M000355'},
#  {'label': 'Kweisi Mfume (D, MD-7)', 'value': 'M000687'},
#  {'label': 'Tracey Mann (R, KS-1)', 'value': 'M000871'},
#  {'label': 'Jerry Moran (R, KS)', 'value': 'M000934'},
#  {'label': 'Patty Murray (D, WA)', 'value': 'M001111'},
#  {'label': 'Lisa C. McClain (R, MI-9)', 'value': 'M001136'},
#  {'label': 'Gregory W. Meeks (D, NY-5)', 'value': 'M001137'},
#  {'label': 'Betty McCollum (D, MN-4)', 'value': 'M001143'},
#  {'label': 'Lisa Murkowski (R, AK)', 'value': 'M001153'},
#  {'label': 'Michael T. McCaul (R, TX-10)', 'value': 'M001157'},
#  {'label': 'Gwen Moore (D, WI-4)', 'value': 'M001160'},
#  {'label': 'Doris O. Matsui (D, CA-7)', 'value': 'M001163'},
#  {'label': 'Christopher Murphy (D, CT)', 'value': 'M001169'},
#  {'label': 'Jeff Merkley (D, OR)', 'value': 'M001176'},
#  {'label': 'Tom McClintock (R, CA-5)', 'value': 'M001177'},
#  {'label': 'Thomas Massie (R, KY-4)', 'value': 'M001184'},
#  {'label': 'Grace Meng (D, NY-6)', 'value': 'M001188'},
#  {'label': 'Markwayne Mullin (R, OK)', 'value': 'M001190'},
#  {'label': 'John R. Moolenaar (R, MI-2)', 'value': 'M001194'},
#  {'label': 'Seth Moulton (D, MA-6)', 'value': 'M001196'},
#  {'label': 'Roger Marshall (R, KS)', 'value': 'M001198'},
#  {'label': 'Brian J. Mast (R, FL-21)', 'value': 'M001199'},
#  {'label': 'Daniel Meuser (R, PA-9)', 'value': 'M001204'},
#  {'label': 'Carol D. Miller (R, WV-1)', 'value': 'M001205'},
#  {'label': 'Joseph D. Morelle (D, NY-25)', 'value': 'M001206'},
#  {'label': 'Lucy McBath (D, GA-6)', 'value': 'M001208'},
#  {'label': 'Gregory F. Murphy (R, NC-3)', 'value': 'M001210'},
#  {'label': 'Mary E. Miller (R, IL-15)', 'value': 'M001211'},
#  {'label': 'Barry Moore (R, AL-1)', 'value': 'M001212'},
#  {'label': 'Blake D. Moore (R, UT-1)', 'value': 'M001213'},
#  {'label': 'Frank J. Mrvan (D, IN-1)', 'value': 'M001214'},
#  {'label': 'Mariannette Miller-Meeks (R, IA-1)', 'value': 'M001215'},
#  {'label': 'Cory Mills (R, FL-7)', 'value': 'M001216'},
#  {'label': 'Jared Moskowitz (D, FL-23)', 'value': 'M001217'},
#  {'label': 'Richard McCormick (R, GA-7)', 'value': 'M001218'},
#  {'label': 'James C. Moylan (R, GU)', 'value': 'M001219'},
#  {'label': 'Morgan McGarvey (D, KY-3)', 'value': 'M001220'},
#  {'label': 'Max L. Miller (R, OH-7)', 'value': 'M001222'},
#  {'label': 'Seth Magaziner (D, RI-2)', 'value': 'M001223'},
#  {'label': 'Nathaniel Moran (R, TX-1)', 'value': 'M001224'},
#  {'label': 'Kevin Mullin (D, CA-15)', 'value': 'M001225'},
#  {'label': 'Robert Menendez (D, NJ-8)', 'value': 'M001226'},
#  {'label': 'Jennifer L. McClellan (D, VA-4)', 'value': 'M001227'},
#  {'label': 'Celeste Maloy (R, UT-2)', 'value': 'M001228'},
#  {'label': 'LaMonica McIver (D, NJ-10)', 'value': 'M001229'},
#  {'label': 'Ryan Mackenzie (R, PA-7)', 'value': 'M001230'},
#  {'label': 'John W. Mannion (D, NY-22)', 'value': 'M001231'},
#  {'label': 'April McClain Delaney (D, MD-6)', 'value': 'M001232'},
#  {'label': 'Mark B. Messmer (R, IN-8)', 'value': 'M001233'},
#  {'label': 'Kelly Morrison (D, MN-3)', 'value': 'M001234'},
#  {'label': 'Riley M. Moore (R, WV-2)', 'value': 'M001235'},
#  {'label': 'Tim Moore (R, NC-14)', 'value': 'M001236'},
#  {'label': 'Kristen McDonald Rivet (D, MI-8)', 'value': 'M001237'},
#  {'label': 'Sarah McBride (D, DE-1)', 'value': 'M001238'},
#  {'label': 'John J. McGuire III (R, VA-5)', 'value': 'M001239'},
#  {'label': 'Addison P. McDowell (R, NC-6)', 'value': 'M001240'},
#  {'label': 'Dave Min (D, CA-47)', 'value': 'M001241'},
#  {'label': 'Bernie Moreno (R, OH)', 'value': 'M001242'},
#  {'label': 'David McCormick (R, PA)', 'value': 'M001243'},
#  {'label': 'Ashley Moody (R, FL)', 'value': 'M001244'},
#  {'label': 'Jerrold Nadler (D, NY-12)', 'value': 'N000002'},
#  {'label': 'Richard E. Neal (D, MA-1)', 'value': 'N000015'},
#  {'label': 'Troy E. Nehls (R, TX-22)', 'value': 'N000026'},
#  {'label': 'Eleanor Holmes Norton (D, DC)', 'value': 'N000147'},
#  {'label': 'Donald Norcross (D, NJ-1)', 'value': 'N000188'},
#  {'label': 'Dan Newhouse (R, WA-4)', 'value': 'N000189'},
#  {'label': 'Ralph Norman (R, SC-5)', 'value': 'N000190'},
#  {'label': 'Joe Neguse (D, CO-2)', 'value': 'N000191'},
#  {'label': 'Zachary Nunn (R, IA-3)', 'value': 'N000193'},
#  {'label': 'Jay Obernolte (R, CA-23)', 'value': 'O000019'},
#  {'label': 'Burgess Owens (R, UT-4)', 'value': 'O000086'},
#  {'label': 'Alexandria Ocasio-Cortez (D, NY-14)', 'value': 'O000172'},
#  {'label': 'Ilhan Omar (D, MN-5)', 'value': 'O000173'},
#  {'label': 'Jon Ossoff (D, GA)', 'value': 'O000174'},
#  {'label': 'Andrew Ogles (R, TN-5)', 'value': 'O000175'},
#  {'label': 'Johnny Olszewski, Jr. (D, MD-2)', 'value': 'O000176'},
#  {'label': 'Robert F. Onder, Jr. (R, MO-3)', 'value': 'O000177'},
#  {'label': 'Frank Pallone, Jr. (D, NJ-6)', 'value': 'P000034'},
#  {'label': 'August Pfluger (R, TX-11)', 'value': 'P000048'},
#  {'label': 'Alex Padilla (D, CA)', 'value': 'P000145'},
#  {'label': 'Nancy Pelosi (D, CA-11)', 'value': 'P000197'},
#  {'label': 'Gary C. Peters (D, MI)', 'value': 'P000595'},
#  {'label': 'Chellie Pingree (D, ME-1)', 'value': 'P000597'},
#  {'label': 'Rand Paul (R, KY)', 'value': 'P000603'},
#  {'label': 'Scott Perry (R, PA-10)', 'value': 'P000605'},
#  {'label': 'Mark Pocan (D, WI-2)', 'value': 'P000607'},
#  {'label': 'Scott H. Peters (D, CA-50)', 'value': 'P000608'},
#  {'label': 'Gary J. Palmer (R, AL-6)', 'value': 'P000609'},
#  {'label': 'Stacey E. Plaskett (D, VI)', 'value': 'P000610'},
#  {'label': 'Jimmy Panetta (D, CA-19)', 'value': 'P000613'},
#  {'label': 'Chris Pappas (D, NH-1)', 'value': 'P000614'},
#  {'label': 'Ayanna Pressley (D, MA-7)', 'value': 'P000617'},
#  {'label': 'Brittany Pettersen (D, CO-7)', 'value': 'P000620'},
#  {'label': 'Nellie Pou (D, NJ-9)', 'value': 'P000621'},
#  {'label': 'Jimmy Patronis (R, FL-1)', 'value': 'P000622'},
#  {'label': 'Mike Quigley (D, IL-5)', 'value': 'Q000023'},
#  {'label': 'Jack Reed (D, RI)', 'value': 'R000122'},
#  {'label': 'Deborah K. Ross (D, NC-2)', 'value': 'R000305'},
#  {'label': 'Harold Rogers (R, KY-5)', 'value': 'R000395'},
#  {'label': 'Mike Rogers (R, AL-3)', 'value': 'R000575'},
#  {'label': 'Patrick Ryan (D, NY-18)', 'value': 'R000579'},
#  {'label': 'James E. Risch (R, ID)', 'value': 'R000584'},
#  {'label': 'Marco Rubio (R, FL)', 'value': 'R000595'},
#  {'label': 'Raul Ruiz (D, CA-25)', 'value': 'R000599'},
#  {'label': 'Aumua Amata Coleman Radewagen (R, AS)', 'value': 'R000600'},
#  {'label': 'David Rouzer (R, NC-7)', 'value': 'R000603'},
#  {'label': 'Mike Rounds (R, SD)', 'value': 'R000605'},
#  {'label': 'Jamie Raskin (D, MD-8)', 'value': 'R000606'},
#  {'label': 'Jacky Rosen (D, NV)', 'value': 'R000608'},
#  {'label': 'John H. Rutherford (R, FL-5)', 'value': 'R000609'},
#  {'label': 'Guy Reschenthaler (R, PA-14)', 'value': 'R000610'},
#  {'label': 'John W. Rose (R, TN-6)', 'value': 'R000612'},
#  {'label': 'Chip Roy (R, TX-21)', 'value': 'R000614'},
#  {'label': 'Delia C. Ramirez (D, IL-3)', 'value': 'R000617'},
#  {'label': 'Pete Ricketts (R, NE)', 'value': 'R000618'},
#  {'label': 'Michael A. Rulli (R, OH-6)', 'value': 'R000619'},
#  {'label': 'Luz M. Rivas (D, CA-29)', 'value': 'R000620'},
#  {'label': 'Emily Randall (D, WA-6)', 'value': 'R000621'},
#  {'label': 'Josh Riley (D, NY-19)', 'value': 'R000622'},
#  {'label': 'Bernard Sanders (I, VT)', 'value': 'S000033'},
#  {'label': 'Charles E. Schumer (D, NY)', 'value': 'S000148'},
#  {'label': 'Maria Elvira Salazar (R, FL-27)', 'value': 'S000168'},
#  {'label': 'Robert C. "Bobby" Scott (D, VA-3)', 'value': 'S000185'},
#  {'label': 'Pete Sessions (R, TX-17)', 'value': 'S000250'},
#  {'label': 'Brad Sherman (D, CA-32)', 'value': 'S000344'},
#  {'label': 'Adam Smith (D, WA-9)', 'value': 'S000510'},
#  {'label': 'Christopher H. Smith (R, NJ-4)', 'value': 'S000522'},
#  {'label': 'Victoria Spartz (R, IN-5)', 'value': 'S000929'},
#  {'label': 'Janice D. Schakowsky (D, IL-9)', 'value': 'S001145'},
#  {'label': 'Michael K. Simpson (R, ID-2)', 'value': 'S001148'},
#  {'label': 'Adam B. Schiff (D, CA)', 'value': 'S001150'},
#  {'label': 'Linda T. Sánchez (D, CA-38)', 'value': 'S001156'},
#  {'label': 'David Scott (D, GA-13)', 'value': 'S001157'},
#  {'label': 'Marilyn Strickland (D, WA-10)', 'value': 'S001159'},
#  {'label': 'Adrian Smith (R, NE-3)', 'value': 'S001172'},
#  {'label': 'Steve Scalise (R, LA-1)', 'value': 'S001176'},
#  {'label': 'Jeanne Shaheen (D, NH)', 'value': 'S001181'},
#  {'label': 'David Schweikert (R, AZ-1)', 'value': 'S001183'},
#  {'label': 'Tim Scott (R, SC)', 'value': 'S001184'},
#  {'label': 'Terri A. Sewell (D, AL-7)', 'value': 'S001185'},
#  {'label': 'Marlin A. Stutzman (R, IN-3)', 'value': 'S001188'},
#  {'label': 'Austin Scott (R, GA-8)', 'value': 'S001189'},
#  {'label': 'Bradley Scott Schneider (D, IL-10)', 'value': 'S001190'},
#  {'label': 'Eric Swalwell (D, CA-14)', 'value': 'S001193'},
#  {'label': 'Brian Schatz (D, HI)', 'value': 'S001194'},
#  {'label': 'Jason Smith (R, MO-8)', 'value': 'S001195'},
#  {'label': 'Elise M. Stefanik (R, NY-21)', 'value': 'S001196'},
#  {'label': 'Dan Sullivan (R, AK)', 'value': 'S001198'},
#  {'label': 'Lloyd Smucker (R, PA-11)', 'value': 'S001199'},
#  {'label': 'Darren Soto (D, FL-9)', 'value': 'S001200'},
#  {'label': 'Thomas R. Suozzi (D, NY-3)', 'value': 'S001201'},
#  {'label': 'Tina Smith (D, MN)', 'value': 'S001203'},
#  {'label': 'Mary Gay Scanlon (D, PA-5)', 'value': 'S001205'},
#  {'label': 'Mikie Sherrill (D, NJ-11)', 'value': 'S001207'},
#  {'label': 'Elissa Slotkin (D, MI)', 'value': 'S001208'},
#  {'label': 'Greg Stanton (D, AZ-4)', 'value': 'S001211'},
#  {'label': 'Pete Stauber (R, MN-8)', 'value': 'S001212'},
#  {'label': 'Bryan Steil (R, WI-1)', 'value': 'S001213'},
#  {'label': 'W. Gregory Steube (R, FL-17)', 'value': 'S001214'},
#  {'label': 'Haley M. Stevens (D, MI-11)', 'value': 'S001215'},
#  {'label': 'Kim Schrier (D, WA-8)', 'value': 'S001216'},
#  {'label': 'Rick Scott (R, FL)', 'value': 'S001217'},
#  {'label': 'Melanie A. Stansbury (D, NM-1)', 'value': 'S001218'},
#  {'label': 'Dale W. Strong (R, AL-5)', 'value': 'S001220'},
#  {'label': 'Hillary J. Scholten (D, MI-3)', 'value': 'S001221'},
#  {'label': 'Emilia Strong Sykes (D, OH-13)', 'value': 'S001223'},
#  {'label': 'Keith Self (R, TX-3)', 'value': 'S001224'},
#  {'label': 'Eric Sorensen (D, IL-17)', 'value': 'S001225'},
#  {'label': 'Andrea Salinas (D, OR-6)', 'value': 'S001226'},
#  {'label': 'Eric Schmitt (R, MO)', 'value': 'S001227'},
#  {'label': 'Derek Schmidt (R, KS-2)', 'value': 'S001228'},
#  {'label': 'Jefferson Shreve (R, IN-6)', 'value': 'S001229'},
#  {'label': 'Suhas Subramanyam (D, VA-10)', 'value': 'S001230'},
#  {'label': 'Lateefah Simon (D, CA-12)', 'value': 'S001231'},
#  {'label': 'Tim Sheehy (R, MT)', 'value': 'S001232'},
#  {'label': 'Thomas P. Tiffany (R, WI-7)', 'value': 'T000165'},
#  {'label': 'Bennie G. Thompson (D, MS-2)', 'value': 'T000193'},
#  {'label': 'John Thune (R, SD)', 'value': 'T000250'},
#  {'label': 'Tommy Tuberville (R, AL)', 'value': 'T000278'},
#  {'label': 'Mike Thompson (D, CA-4)', 'value': 'T000460'},
#  {'label': 'Michael R. Turner (R, OH-10)', 'value': 'T000463'},
#  {'label': 'Glenn Thompson (R, PA-15)', 'value': 'T000467'},
#  {'label': 'Dina Titus (D, NV-1)', 'value': 'T000468'},
#  {'label': 'Paul Tonko (D, NY-20)', 'value': 'T000469'},
#  {'label': 'Mark Takano (D, CA-39)', 'value': 'T000472'},
#  {'label': 'Norma J. Torres (D, CA-35)', 'value': 'T000474'},
#  {'label': 'Thom Tillis (R, NC)', 'value': 'T000476'},
#  {'label': 'Claudia Tenney (R, NY-24)', 'value': 'T000478'},
#  {'label': 'William R. Timmons IV (R, SC-4)', 'value': 'T000480'},
#  {'label': 'Rashida Tlaib (D, MI-12)', 'value': 'T000481'},
#  {'label': 'Lori Trahan (D, MA-3)', 'value': 'T000482'},
#  {'label': 'Ritchie Torres (D, NY-15)', 'value': 'T000486'},
#  {'label': 'Jill N. Tokuda (D, HI-2)', 'value': 'T000487'},
#  {'label': 'Shri Thanedar (D, MI-13)', 'value': 'T000488'},
#  {'label': 'Sylvester Turner (D, TX-18)', 'value': 'T000489'},
#  {'label': 'David J. Taylor (R, OH-2)', 'value': 'T000490'},
#  {'label': 'Derek Tran (D, CA-45)', 'value': 'T000491'},
#  {'label': 'Lauren Underwood (D, IL-14)', 'value': 'U000040'},
#  {'label': 'Nydia M. Velázquez (D, NY-7)', 'value': 'V000081'},
#  {'label': 'Chris Van Hollen (D, MD)', 'value': 'V000128'},
#  {'label': 'David G. Valadao (R, CA-22)', 'value': 'V000129'},
#  {'label': 'Juan Vargas (D, CA-52)', 'value': 'V000130'},
#  {'label': 'Marc A. Veasey (D, TX-33)', 'value': 'V000131'},
#  {'label': 'Jefferson Van Drew (R, NJ-2)', 'value': 'V000133'},
#  {'label': 'Beth Van Duyne (R, TX-24)', 'value': 'V000134'},
#  {'label': 'Derrick Van Orden (R, WI-3)', 'value': 'V000135'},
#  {'label': 'Gabe Vasquez (D, NM-2)', 'value': 'V000136'},
#  {'label': 'J. D. Vance (R, OH)', 'value': 'V000137'},
#  {'label': 'Eugene Simon Vindman (D, VA-7)', 'value': 'V000138'},
#  {'label': 'Maxine Waters (D, CA-43)', 'value': 'W000187'},
#  {'label': 'Roger F. Wicker (R, MS)', 'value': 'W000437'},
#  {'label': 'Ron Wyden (D, OR)', 'value': 'W000779'},
#  {'label': 'Nikema Williams (D, GA-5)', 'value': 'W000788'},
#  {'label': 'Raphael G. Warnock (D, GA)', 'value': 'W000790'},
#  {'label': 'Joe Wilson (R, SC-2)', 'value': 'W000795'},
#  {'label': 'Debbie Wasserman Schultz (D, FL-25)', 'value': 'W000797'},
#  {'label': 'Tim Walberg (R, MI-5)', 'value': 'W000798'},
#  {'label': 'Peter Welch (D, VT)', 'value': 'W000800'},
#  {'label': 'Sheldon Whitehouse (D, RI)', 'value': 'W000802'},
#  {'label': 'Robert J. Wittman (R, VA-1)', 'value': 'W000804'},
#  {'label': 'Mark R. Warner (D, VA)', 'value': 'W000805'},
#  {'label': 'Daniel Webster (R, FL-11)', 'value': 'W000806'},
#  {'label': 'Frederica S. Wilson (D, FL-24)', 'value': 'W000808'},
#  {'label': 'Steve Womack (R, AR-3)', 'value': 'W000809'},
#  {'label': 'Ann Wagner (R, MO-2)', 'value': 'W000812'},
#  {'label': 'Randy K. Weber, Sr. (R, TX-14)', 'value': 'W000814'},
#  {'label': 'Roger Williams (R, TX-25)', 'value': 'W000816'},
#  {'label': 'Elizabeth Warren (D, MA)', 'value': 'W000817'},
#  {'label': 'Bruce Westerman (R, AR-4)', 'value': 'W000821'},
#  {'label': 'Bonnie Watson Coleman (D, NJ-12)', 'value': 'W000822'},
#  {'label': 'Michael Waltz (R, FL-6)', 'value': 'W000823'},
#  {'label': 'Tony Wied (R, WI-8)', 'value': 'W000829'},
#  {'label': 'George Whitesides (D, CA-27)', 'value': 'W000830'},
#  {'label': 'James R. Walkinshaw (D, VA-11)', 'value': 'W000831'},
#  {'label': 'Todd Young (R, IN)', 'value': 'Y000064'},
#  {'label': 'Rudy Yakym III (R, IN-2)', 'value': 'Y000067'},
#  {'label': 'Ryan K. Zinke (R, MT-1)', 'value': 'Z000018'}]

# %%
pd.read_sql_query(myquery, con=engine).T
# Out:
#                                                                    0    \
# bioguide_id                                                    A000055
# full_name                                           Robert B. Aderholt
# birthyear                                                       1965.0
# image                https://www.congress.gov/img/member/a000055_20...
# office_address       272 Cannon House Office Building, Washington, ...
# phone                                                   (202) 225-4876
# website                                    https://aderholt.house.gov/
# fec_id                                                       H6AL04098
# bioname                                               ADERHOLT, Robert
# chamber                                                          House
# left_right_ideology                                              0.405
# state_abbrev                                                        AL
# district_code                                                        4
# icpsr                                                            29701
# party                                                       Republican
#
#                                                                    1    \
# bioguide_id                                                    A000148
# full_name                                             Jake Auchincloss
# birthyear                                                       1988.0
# image                https://www.congress.gov/img/member/67817e391f...
# office_address       1524 Longworth House Office Building, Washingt...
# phone                                                   (202) 225-5931
# website                                  https://auchincloss.house.gov
# fec_id                                                       H0MA04192
# bioname                                              AUCHINCLOSS, Jake
# chamber                                                          House
# left_right_ideology                                             -0.288
# state_abbrev                                                        MA
# district_code                                                        4
# icpsr                                                            22100
# party                                                         Democrat
#
#                                                                    2    \
# bioguide_id                                                    A000369
# full_name                                               Mark E. Amodei
# birthyear                                                       1958.0
# image                https://www.congress.gov/img/member/a000369_20...
# office_address       104 Cannon House Office Building, Washington, ...
# phone                                                   (202) 225-6155
# website                                       https://amodei.house.gov
# fec_id                                                       H2NV02395
# bioname                                                AMODEI, Mark E.
# chamber                                                          House
# left_right_ideology                                              0.384
# state_abbrev                                                        NV
# district_code                                                        2
# icpsr                                                            21196
# party                                                       Republican
#
#                                                                    3    \
# bioguide_id                                                    A000370
# full_name                                                Alma S. Adams
# birthyear                                                       1946.0
# image                https://www.congress.gov/img/member/a000370_20...
# office_address       2436 Rayburn House Office Building, Washington...
# phone                                                   (202) 225-1510
# website                                        https://adams.house.gov
# fec_id                                                       H4NC12100
# bioname                                                    ADAMS, Alma
# chamber                                                          House
# left_right_ideology                                             -0.462
# state_abbrev                                                        NC
# district_code                                                       12
# icpsr                                                            21545
# party                                                         Democrat
#
#                                                                    4    \
# bioguide_id                                                    A000371
# full_name                                                 Pete Aguilar
# birthyear                                                       1979.0
# image                https://www.congress.gov/img/member/a000371_20...
# office_address       108 Cannon House Office Building, Washington, ...
# phone                                                   (202) 225-3201
# website                                     https://aguilar.house.gov/
# fec_id                                                       H2CA31125
# bioname                                             AGUILAR, Peter Rey
# chamber                                                          House
# left_right_ideology                                             -0.324
# state_abbrev                                                        CA
# district_code                                                       33
# icpsr                                                            21506
# party                                                         Democrat
#
#                                                                    5    \
# bioguide_id                                                    A000372
# full_name                                                Rick W. Allen
# birthyear                                                       1951.0
# image                https://www.congress.gov/img/member/a000372_20...
# office_address       462 Cannon House Office Building, Washington, ...
# phone                                                   (202) 225-2823
# website                                        https://allen.house.gov
# fec_id                                                       H2GA12048
# bioname                                                 ALLEN, Rick W.
# chamber                                                          House
# left_right_ideology                                               0.69
# state_abbrev                                                        GA
# district_code                                                       12
# icpsr                                                            21516
# party                                                       Republican
#
#                                                                    6    \
# bioguide_id                                                    A000375
# full_name                                           Jodey C. Arrington
# birthyear                                                       1972.0
# image                https://www.congress.gov/img/member/115_rp_tx_...
# office_address       1111 Longworth House Office Building, Washingt...
# phone                                                   (202) 225-4005
# website                                    https://arrington.house.gov
# fec_id                                                       H6TX19099
# bioname                                          ARRINGTON, Jodey Cook
# chamber                                                          House
# left_right_ideology                                              0.642
# state_abbrev                                                        TX
# district_code                                                       19
# icpsr                                                            21700
# party                                                       Republican
#
#                                                                    7    \
# bioguide_id                                                    A000379
# full_name                                                  Mark Alford
# birthyear                                                       1963.0
# image                https://www.congress.gov/img/member/a000379_20...
# office_address       328 Cannon House Office Building, Washington, ...
# phone                                                   (202) 225-2876
# website                                       https://alford.house.gov
# fec_id                                                       H2MO04207
# bioname                                                   ALFORD, Mark
# chamber                                                          House
# left_right_ideology                                              0.569
# state_abbrev                                                        MO
# district_code                                                        4
# icpsr                                                            22300
# party                                                       Republican
#
#                                                                    8    \
# bioguide_id                                                    A000380
# full_name                                                     Gabe Amo
# birthyear                                                       1987.0
# image                https://www.congress.gov/img/member/669ace45fa...
# office_address       1119 Longworth House Office Building, Washingt...
# phone                                                   (202) 225-4911
# website                                          https://amo.house.gov
# fec_id                                                       H4RI01265
# bioname                                                      AMO, Gabe
# chamber                                                          House
# left_right_ideology                                             -0.456
# state_abbrev                                                        RI
# district_code                                                        1
# icpsr                                                            22375
# party                                                         Democrat
#
#                                                                    9    ...  \
# bioguide_id                                                    A000381  ...
# full_name                                              Yassamin Ansari  ...
# birthyear                                                       1992.0  ...
# image                https://www.congress.gov/img/member/67741fc30b...  ...
# office_address       1432 Longworth House Office Building, Washingt...  ...
# phone                                                   (202) 225-4065  ...
# website                                      https://ansari.house.gov/  ...
# fec_id                                                       H4AZ03109  ...
# bioname                                               ANSARI, Yassamin  ...
# chamber                                                          House  ...
# left_right_ideology                                             -0.506  ...
# state_abbrev                                                        AZ  ...
# district_code                                                        3  ...
# icpsr                                                            22500  ...
# party                                                         Democrat  ...
#
#                                                                    535  \
# bioguide_id                                                    W000817
# full_name                                             Elizabeth Warren
# birthyear                                                       1949.0
# image                https://www.congress.gov/img/member/w000817_20...
# office_address       311 Hart Senate Office Building  Washington, D...
# phone                                                   (202) 224-4543
# website                                  https://www.warren.senate.gov
# fec_id                                                       S2MA00170
# bioname                                              WARREN, Elizabeth
# chamber                                                         Senate
# left_right_ideology                                             -0.744
# state_abbrev                                                        MA
# district_code                                                        0
# icpsr                                                            41301
# party                                                         Democrat
#
#                                                                    536  \
# bioguide_id                                                    W000821
# full_name                                              Bruce Westerman
# birthyear                                                       1967.0
# image                https://www.congress.gov/img/member/w000821_20...
# office_address       202 Cannon House Office Building, Washington, ...
# phone                                                   (202) 225-3772
# website                                   https://westerman.house.gov/
# fec_id                                                       H4AR04048
# bioname                                        WESTERMAN, Bruce Eugene
# chamber                                                          House
# left_right_ideology                                              0.544
# state_abbrev                                                        AR
# district_code                                                        4
# icpsr                                                            21563
# party                                                       Republican
#
#                                                                    537  \
# bioguide_id                                                    W000822
# full_name                                        Bonnie Watson Coleman
# birthyear                                                       1945.0
# image                https://www.congress.gov/img/member/w000822_20...
# office_address       168 Cannon House Office Building, Washington, ...
# phone                                                   (202) 225-5801
# website                               https://watsoncoleman.house.gov/
# fec_id                                                       H4NJ12149
# bioname                                         WATSON COLEMAN, Bonnie
# chamber                                                          House
# left_right_ideology                                             -0.597
# state_abbrev                                                        NJ
# district_code                                                       12
# icpsr                                                            21538
# party                                                         Democrat
#
#                                                                    538  \
# bioguide_id                                                    W000823
# full_name                                                Michael Waltz
# birthyear                                                       1974.0
# image                https://www.congress.gov/img/member/w000823_20...
# office_address                                                    None
# phone                                                             None
# website                                                           None
# fec_id                                                       H8FL06148
# bioname                                                 WALTZ, Michael
# chamber                                                          House
# left_right_ideology                                              0.452
# state_abbrev                                                        FL
# district_code                                                        6
# icpsr                                                            21981
# party                                                       Republican
#
#                                                                    539  \
# bioguide_id                                                    W000829
# full_name                                                    Tony Wied
# birthyear                                                       1976.0
# image                https://www.congress.gov/img/member/6734b6724c...
# office_address       424 Cannon House Office Building, Washington, ...
# phone                                                   (202) 225-5665
# website                                        https://wied.house.gov/
# fec_id                                                       H4WI08119
# bioname                                                     WIED, Tony
# chamber                                                          House
# left_right_ideology                                              0.484
# state_abbrev                                                        WI
# district_code                                                        8
# icpsr                                                            22383
# party                                                       Republican
#
#                                                                    540  \
# bioguide_id                                                    W000830
# full_name                                            George Whitesides
# birthyear                                                       1974.0
# image                https://www.congress.gov/img/member/68dc43db19...
# office_address       1504 Longworth House Office Building, Washingt...
# phone                                                   (202) 225-1956
# website                                  https://whitesides.house.gov/
# fec_id                                                       H4CA27111
# bioname                                             WHITESIDES, George
# chamber                                                          House
# left_right_ideology                                             -0.189
# state_abbrev                                                        CA
# district_code                                                       27
# icpsr                                                            22559
# party                                                         Democrat
#
#                                                                    541  \
# bioguide_id                                                    W000831
# full_name                                          James R. Walkinshaw
# birthyear                                                       1982.0
# image                https://www.congress.gov/img/member/68c1bd4ca9...
# office_address       2265 Rayburn House Office Building, Washington...
# phone                                                   (202) 225-1492
# website                                  https://walkinshaw.house.gov/
# fec_id                                                       H6VA11066
# bioname                                           WALKINSHAW, James R.
# chamber                                                          House
# left_right_ideology                                             -0.503
# state_abbrev                                                        VA
# district_code                                                       11
# icpsr                                                            22564
# party                                                         Democrat
#
#                                                                    542  \
# bioguide_id                                                    Y000064
# full_name                                                   Todd Young
# birthyear                                                       1972.0
# image                https://www.congress.gov/img/member/y000064_20...
# office_address       185 Dirksen Senate Office Building  Washington...
# phone                                                   (202) 224-5623
# website                                   https://www.young.senate.gov
# fec_id                                                       S0IN00194
# bioname                                                    YOUNG, Todd
# chamber                                                         Senate
# left_right_ideology                                              0.438
# state_abbrev                                                        IN
# district_code                                                        0
# icpsr                                                            21133
# party                                                       Republican
#
#                                                                    543  \
# bioguide_id                                                    Y000067
# full_name                                               Rudy Yakym III
# birthyear                                                       1984.0
# image                https://www.congress.gov/img/member/y000067_20...
# office_address       349 Cannon House Office Building, Washington, ...
# phone                                                   (202) 225-3915
# website                                        https://yakym.house.gov
# fec_id                                                       H2IN02295
# bioname                                               YAKYM, Rudy, III
# chamber                                                          House
# left_right_ideology                                              0.513
# state_abbrev                                                        IN
# district_code                                                        2
# icpsr                                                            22171
# party                                                       Republican
#
#                                                                    544
# bioguide_id                                                    Z000018
# full_name                                                Ryan K. Zinke
# birthyear                                                       1961.0
# image                https://www.congress.gov/img/member/117_rp_mt_...
# office_address       512 Cannon House Office Building, Washington, ...
# phone                                                   (202) 225-5628
# website                                        https://zinke.house.gov
# fec_id                                                       H4MT01041
# bioname                                                    ZINKE, Ryan
# chamber                                                          House
# left_right_ideology                                              0.438
# state_abbrev                                                        MT
# district_code                                                        1
# icpsr                                                            21532
# party                                                       Republican
#
# [15 rows x 545 columns]

# %%
b = 'A000055'

myquery = f'''
SELECT *
FROM members
WHERE bioguide_id = '{b}'
'''
member_info = pd.read_sql_query(myquery, con=engine)
member_info = member_info.drop(['bioguide_id', 'image', 'fec_id', 'bioname', 'icpsr'],
    axis=1)
ff.create_table(member_info.T.reset_index().rename({'index':'',0:''}, axis=1))

# %%
myquery = f'''
SELECT image
FROM members
WHERE bioguide_id = '{b}'
'''
pd.read_sql_query(myquery, con=engine)['image'][0]
# Out:
# 'https://www.congress.gov/img/member/a000055_200.jpg'

# %%
myquery = f'''
SELECT c.comparison_member,
    c.agree,
    m.left_right_ideology,
    m.party
FROM members m
INNER JOIN (
    SELECT vc.comparison_member,
        vc.agree
    FROM members m
    INNER JOIN vote_compare vc
        ON m.bioname = vc.bioname
    WHERE m.bioguide_id = '{b}'
) c
    ON m.bioname = c.comparison_member

'''
pd.read_sql_query(myquery, con=engine)
# Out:
#            comparison_member     agree  left_right_ideology       party
# 0         DIAZ-BALART, Mario  0.928826                0.281  Republican
# 1               SCOTT, David  0.345196               -0.304    Democrat
# 2                   CASE, Ed  0.355872               -0.205    Democrat
# 3         TURNER, Michael R.  0.900356                0.265  Republican
# 4                  COLE, Tom  0.950178                0.323  Republican
# ..                       ...       ...                  ...         ...
# 437       GIMENEZ, Carlos A.  0.921708                0.332  Republican
# 438           GONZALES, Tony  0.911032                0.346  Republican
# 439  GREENE, Marjorie Taylor  0.768683                0.800  Republican
# 440       HARSHBARGER, Diana  0.854093                0.675  Republican
# 441      VAN DREW, Jefferson  0.921708                0.382  Republican
#
# [442 rows x 4 columns]

# %%
myquery = f'''



SELECT c.comparison_member,
    c.agree,
    m.left_right_ideology,
    m.party
FROM members m
INNER JOIN (SELECT vc.comparison_member, vc.agree
FROM members m
INNER JOIN vote_compare vc
    ON m.bioname = vc.bioname
WHERE bioguide_id = '{b}') c
    ON m.bioname = c.comparison_member


'''

vote_data = pd.read_sql_query(myquery, con=engine)

# %%
import plotly.express as px

# %%
fig = px.scatter(vote_data,
                 x = 'left_right_ideology',
                 y = 'agree',
                 hover_name = 'comparison_member',
                 color = 'party',
                 color_discrete_map={'Democrat': 'blue','Republican': 'red'})
fig.show()

# Color mapping for parties
