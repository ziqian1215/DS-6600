# %%
import numpy as np 
import pandas as pd 
import psycopg
from sqlalchemy import create_engine
import dotenv
import os
dotenv.load_dotenv()
# Out:
# True

# %%
PROSTGRES_PASSWORD = os.getenv('POSTGRES_PASSWORD')

# %%
bill_versions = pd.read_csv('../data/thirdNF/bill_versions.csv')
bills = pd.read_csv('../data/thirdNF/bills.csv')
vote_compare = pd.read_csv('../data/thirdNF/vote_compare.csv')
terms = pd.read_csv('../data/thirdNF/terms.csv')
members = pd.read_csv('../data/thirdNF/members.csv')

# %% [markdown]
# ## Step 1: After docker compose up and loading the data, connect to the Postgres serve

# %%
dbserve = psycopg.connect(
    host = "localhost",
    port = "5432",
    user = "postgres",
    password = PROSTGRES_PASSWORD       
)
dbserve.autocommit = True

# %% [markdown]
# ## Step 2: Create an empty contrans dataframe on the serve

# %%
cursor = dbserve.cursor()
try:
    cursor.execute("CREATE DATABASE contrans")
except:
    cursor.execute("DROP DATABASE contrans")
    cursor.execute("CREATE DATABASE contrans")

# %% [markdown]
# ## Step 3: Create a connection to the new empty database using a convenience tool called SQLalchemy

# %%
dbms = 'postgresql'
package = 'psycopg'
user = 'postgres'
password = PROSTGRES_PASSWORD
host = 'localhost'
port = '5432'
db = 'contrans'

engine = create_engine(f'{dbms}+{package}://{user}:{password}@{host}:{port}/{db}')
engine
# Out:
# Engine(postgresql+psycopg://postgres:***@localhost:5432/contrans)

# %% [markdown]
# ## Step 4: Upload the data to our new postgres contrans DB

# %%
bills.columns = [c.lower().replace('.', '_') for c in bills.columns]
terms.columns = [c.lower().replace('.', '_') for c in terms.columns]
members.columns = [c.lower().replace('.', '_') for c in members.columns]
bill_versions.columns = [c.lower().replace('.', '_') for c in bill_versions.columns]
vote_compare.columns = [c.lower().replace('.', '_') for c in vote_compare.columns]

bills.to_sql('bills', con=engine, if_exists='replace', index=False, chunksize=1000)
terms.to_sql('terms', con=engine, if_exists='replace', index=False, chunksize=1000)
members.to_sql('members', con=engine, if_exists='replace', index=False, chunksize=1000)
bill_versions.to_sql('bill_versions', con=engine, if_exists='replace', index=False, chunksize=1000)
vote_compare.to_sql('vote_compare', con=engine, if_exists='replace', index=False, chunksize=1000)
# Out:
# -207

# %% [markdown]
# The previous four steps are things you do one time -- to build the database.
#
# Next are steps you do EACH time you want to query the database.
#
# #### Step 1: Docker compse up
#
# #### Step 2: Build the SQLalchemy engine
#
# #### Step 3: Use pd.read_sql_query() to issue SQL queries

# %%
myquery = '''
SELECT *
FROM members
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#     bioguide_id            full_name                   chamber  birthyear  \
# 0       A000055   Robert B. Aderholt  House of Representatives     1965.0
# 1       A000148     Jake Auchincloss  House of Representatives     1988.0
# 2       A000369       Mark E. Amodei  House of Representatives     1958.0
# 3       A000370        Alma S. Adams  House of Representatives     1946.0
# 4       A000371         Pete Aguilar  House of Representatives     1979.0
# ..          ...                  ...                       ...        ...
# 540     W000830    George Whitesides  House of Representatives     1974.0
# 541     W000831  James R. Walkinshaw  House of Representatives     1982.0
# 542     Y000064           Todd Young                    Senate     1972.0
# 543     Y000067       Rudy Yakym III  House of Representatives     1984.0
# 544     Z000018        Ryan K. Zinke  House of Representatives     1961.0
#
#                                                  image  \
# 0    https://www.congress.gov/img/member/a000055_20...
# 1    https://www.congress.gov/img/member/67817e391f...
# 2    https://www.congress.gov/img/member/a000369_20...
# 3    https://www.congress.gov/img/member/a000370_20...
# 4    https://www.congress.gov/img/member/a000371_20...
# ..                                                 ...
# 540  https://www.congress.gov/img/member/68dc43db19...
# 541  https://www.congress.gov/img/member/68c1bd4ca9...
# 542  https://www.congress.gov/img/member/y000064_20...
# 543  https://www.congress.gov/img/member/y000067_20...
# 544  https://www.congress.gov/img/member/117_rp_mt_...
#
#                                         office_address           phone  \
# 0    272 Cannon House Office Building, Washington, ...  (202) 225-4876
# 1    1524 Longworth House Office Building, Washingt...  (202) 225-5931
# 2    104 Cannon House Office Building, Washington, ...  (202) 225-6155
# 3    2436 Rayburn House Office Building, Washington...  (202) 225-1510
# 4    108 Cannon House Office Building, Washington, ...  (202) 225-3201
# ..                                                 ...             ...
# 540  1504 Longworth House Office Building, Washingt...  (202) 225-1956
# 541  2265 Rayburn House Office Building, Washington...  (202) 225-1492
# 542  185 Dirksen Senate Office Building  Washington...  (202) 224-5623
# 543  349 Cannon House Office Building, Washington, ...  (202) 225-3915
# 544  512 Cannon House Office Building, Washington, ...  (202) 225-5628
#
#                            website     fec_id  left_right_ideology  \
# 0      https://aderholt.house.gov/  H6AL04098                0.405
# 1    https://auchincloss.house.gov  H0MA04192               -0.288
# 2         https://amodei.house.gov  H2NV02395                0.384
# 3          https://adams.house.gov  H4NC12100               -0.462
# 4       https://aguilar.house.gov/  H2CA31125               -0.324
# ..                             ...        ...                  ...
# 540  https://whitesides.house.gov/  H4CA27111               -0.189
# 541  https://walkinshaw.house.gov/  H6VA11066               -0.503
# 542   https://www.young.senate.gov  S0IN00194                0.438
# 543        https://yakym.house.gov  H2IN02295                0.513
# 544        https://zinke.house.gov  H4MT01041                0.438
#
#     state_abbrev  district_code  icpsr       party
# 0             AL              4  29701  Republican
# 1             MA              4  22100    Democrat
# 2             NV              2  21196  Republican
# 3             NC             12  21545    Democrat
# 4             CA             33  21506    Democrat
# ..           ...            ...    ...         ...
# 540           CA             27  22559    Democrat
# 541           VA             11  22564    Democrat
# 542           IN              0  21133  Republican
# 543           IN              2  22171  Republican
# 544           MT              1  21532  Republican
#
# [545 rows x 14 columns]

# %% [markdown]
# SQL: Structured Query Language
#
# "Sequel", "Essqueueell" -- accpectable
# "Squall", "Squirrel" -- not usually accpectable
#
# Clauses: functions for data manipulation
#
# * SELECT: keeping only certain columns
#
# * FORM: load data from a particular table in the DB
#
# * AS: renaming a column on the fly

# %% [markdown]
# SQL Etiquette
#
# The following quety WORKS but is considered bad etiquette

# %%
myquery = '''
SELECT bioguide_id AS congressmember,
       congress AS wtf,
       statecode AS state,
       district AS dist
FROM terms
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#      congressmember  wtf state  dist
# 0           R000575  108    AL   3.0
# 1           R000575  109    AL   3.0
# 2           R000575  110    AL   3.0
# 3           R000575  111    AL   3.0
# 4           R000575  112    AL   3.0
# ...             ...  ...   ...   ...
# 3252        B001261  115    WY   NaN
# 3253        B001261  116    WY   NaN
# 3254        B001261  117    WY   NaN
# 3255        B001261  118    WY   NaN
# 3256        B001261  119    WY   NaN
#
# [3257 rows x 4 columns]

# %% [markdown]
# The purpose of etiquette rules os to make your SQL easier for someone else (and yourself) to read and understand. You can break these rules and get the same result, but you will annoy people who are working with you.
#
# Rules:
# 1. Clauses in ALL CAPS
# 2. column names and table names in lowercase
# 3. Every clause on a new line, with some exceptions such as AS
# 4. If a clause is considered to be part of a prior one (such as ON is part of JOIN), it is placed on a new line, but with a tab

# %% [markdown]
# * WHERE: keeping only rows where a given logical statement is true

# %%
myquery = '''
SELECT *
FROM members
WHERE state_abbrev = 'VA'
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#    bioguide_id                full_name                   chamber  birthyear  \
# 0      B001292     Donald S. Beyer, Jr.  House of Representatives     1950.0
# 1      C001078       Gerald E. Connolly  House of Representatives     1950.0
# 2      C001118                Ben Cline  House of Representatives     1972.0
# 3      G000568       H. Morgan Griffith  House of Representatives     1958.0
# 4      K000384                Tim Kaine                    Senate     1958.0
# 5      K000399      Jennifer A. Kiggans  House of Representatives     1971.0
# 6      M001227    Jennifer L. McClellan  House of Representatives     1972.0
# 7      M001239      John J. McGuire III  House of Representatives     1968.0
# 8      S000185  Robert C. "Bobby" Scott  House of Representatives     1947.0
# 9      S001230        Suhas Subramanyam  House of Representatives     1986.0
# 10     V000138     Eugene Simon Vindman  House of Representatives     1975.0
# 11     W000804        Robert J. Wittman  House of Representatives     1959.0
# 12     W000805           Mark R. Warner                    Senate     1954.0
# 13     W000831      James R. Walkinshaw  House of Representatives     1982.0
#
#                                                 image  \
# 0   https://www.congress.gov/img/member/b001292_20...
# 1   https://www.congress.gov/img/member/c001078_20...
# 2   https://www.congress.gov/img/member/c001118_20...
# 3   https://www.congress.gov/img/member/68094df86c...
# 4   https://www.congress.gov/img/member/k000384_20...
# 5   https://www.congress.gov/img/member/66b0ce45b0...
# 6   https://www.congress.gov/img/member/m001227_20...
# 7   https://www.congress.gov/img/member/67744ba20b...
# 8   https://www.congress.gov/img/member/s000185_20...
# 9   https://www.congress.gov/img/member/6797be8bc7...
# 10  https://www.congress.gov/img/member/6774617a0b...
# 11  https://www.congress.gov/img/member/w000804_20...
# 12  https://www.congress.gov/img/member/w000805_20...
# 13  https://www.congress.gov/img/member/68c1bd4ca9...
#
#                                        office_address           phone  \
# 0   1226 Longworth House Office Building, Washingt...  (202) 225-4376
# 1                                                None            None
# 2   2443 Rayburn House Office Building, Washington...  (202) 225-5431
# 3   2110 Rayburn House Office Building, Washington...  (202) 225-3861
# 4   231 Russell Senate Office Building  Washington...  (202) 224-4024
# 5   152 Cannon House Office Building, Washington, ...  (202) 225-4215
# 6   1628 Longworth House Office Building, Washingt...  (202) 225-6365
# 7   1013 Longworth House Office Building, Washingt...  (202) 225-4711
# 8   2328 Rayburn House Office Building, Washington...  (202) 225-8351
# 9   1009 Longworth House Office Building, Washingt...  (202) 225-5136
# 10  1005 Longworth House Office Building, Washingt...  (202) 225-2815
# 11  2055 Rayburn House Office Building, Washington...  (202) 225-4261
# 12  703 Hart Senate Office Building  Washington, D...  (202) 224-2023
# 13  2265 Rayburn House Office Building, Washington...  (202) 225-1492
#
#                               website     fec_id  left_right_ideology  \
# 0             https://beyer.house.gov  H4VA08224               -0.395
# 1                                None  H8VA11062               -0.309
# 2             https://cline.house.gov  H8VA06104                0.716
# 3   https://morgangriffith.house.gov/  H0VA09055                0.510
# 4       https://www.kaine.senate.gov/  S2VA00142               -0.243
# 5           https://kiggans.house.gov  H2VA02064                0.260
# 6        https://mcclellan.house.gov/  H4VA04066               -0.550
# 7          https://mcguire.house.gov/  H0VA07133                0.673
# 8        https://bobbyscott.house.gov  H6VA01117               -0.450
# 9      https://subramanyam.house.gov/  H4VA10279               -0.301
# 10         https://vindman.house.gov/  H4VA07234               -0.168
# 11         https://wittman.house.gov/  H8VA01147                0.448
# 12      https://www.warner.senate.gov  S8VA00107               -0.208
# 13      https://walkinshaw.house.gov/  H6VA11066               -0.503
#
#    state_abbrev  district_code  icpsr       party
# 0            VA              8  21554    Democrat
# 1            VA             11  20952    Democrat
# 2            VA              6  21908  Republican
# 3            VA              9  21191  Republican
# 4            VA              0  41305    Democrat
# 5            VA              2  22335  Republican
# 6            VA              4  22374    Democrat
# 7            VA              5  22539  Republican
# 8            VA              3  39307    Democrat
# 9            VA             10  22554    Democrat
# 10           VA              7  22558    Democrat
# 11           VA              1  20756  Republican
# 12           VA              0  40909    Democrat
# 13           VA             11  22564    Democrat

# %%
myquery = '''
SELECT *
FROM terms
WHERE (congress >= 110 AND congress <= 110)
    OR statecode = 'VA'
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#     bioguide_id                   chamber  congress statecode  startyear  \
# 0       R000575  House of Representatives       110        AL       2007
# 1       A000055  House of Representatives       110        AL       2007
# 2       G000551  House of Representatives       110        AZ       2007
# 3       P000197  House of Representatives       110        CA       2007
# 4       I000056  House of Representatives       110        CA       2007
# ..          ...                       ...       ...       ...        ...
# 173     C000127                    Senate       110        WA       2007
# 174     M001111                    Senate       110        WA       2007
# 175     C001047  House of Representatives       110        WV       2007
# 176     B001230  House of Representatives       110        WI       2007
# 177     B001261                    Senate       110        WY       2007
#
#      endyear  district
# 0       2009       3.0
# 1       2009       4.0
# 2       2009       7.0
# 3       2009       8.0
# 4       2009      49.0
# ..       ...       ...
# 173     2009       NaN
# 174     2009       NaN
# 175     2009       2.0
# 176     2009       2.0
# 177     2009       NaN
#
# [178 rows x 7 columns]

# %% [markdown]
# * GROUPBY: aggregate data to one row per unique of the groupby column(s)

# %%
myquery = '''
SELECT state_abbrev,
    AVG(left_right_ideology) AS avg_ideology
FROM members
GROUP BY state_abbrev
ORDER BY avg_ideology
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#    state_abbrev  avg_ideology
# 0            DC     -0.491000
# 1            VI     -0.474000
# 2            VT     -0.467667
# 3            PR     -0.463000
# 4            MA     -0.430182
# 5            HI     -0.409500
# 6            RI     -0.375750
# 7            NM     -0.370600
# 8            CT     -0.348143
# 9            DE     -0.290333
# 10           MD     -0.283600
# 11           NJ     -0.263857
# 12           CA     -0.259222
# 13           IL     -0.251789
# 14           WA     -0.244667
# 15           OR     -0.241625
# 16           NH     -0.234250
# 17           NY     -0.200964
# 18           NV     -0.182833
# 19           ME     -0.143250
# 20           VA     -0.037143
# 21           MN     -0.001200
# 22           CO      0.000900
# 23           MI      0.049467
# 24           PA      0.093895
# 25           AZ      0.160091
# 26           MP      0.164000
# 27           GA      0.215000
# 28           WI      0.222500
# 29           TX      0.275700
# 30           LA      0.279125
# 31           OH      0.294000
# 32           FL      0.306219
# 33           AS      0.326000
# 34           MS      0.336167
# 35           NC      0.360625
# 36           IN      0.375818
# 37           AL      0.377556
# 38           GU      0.390000
# 39           IA      0.391333
# 40           KY      0.412375
# 41           MO      0.415000
# 42           SD      0.416667
# 43           NE      0.428400
# 44           AK      0.437667
# 45           SC      0.464111
# 46           AR      0.465833
# 47           ND      0.470333
# 48           KS      0.471667
# 49           ID      0.500000
# 50           OK      0.536714
# 51           TN      0.539545
# 52           UT      0.563833
# 53           WV      0.566000
# 54           WY      0.625000
# 55           MT      0.637750

# %% [markdown]
# * HAVING: like WHERE but filetering rows after aggregration

# %%
myquery = '''
SELECT state_abbrev,
    AVG(left_right_ideology) AS avg_ideology
FROM members
WHERE party = 'Democrat'
GROUP BY state_abbrev
    HAVING AVG(left_right_ideology) < -.25
ORDER BY avg_ideology
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#    state_abbrev  avg_ideology
# 0            MS     -0.519000
# 1            WI     -0.511333
# 2            MO     -0.510000
# 3            KY     -0.500000
# 4            DC     -0.491000
# 5            LA     -0.483500
# 6            VI     -0.474000
# 7            TX     -0.469769
# 8            SC     -0.467000
# 9            PR     -0.463000
# 10           MA     -0.430182
# 11           VT     -0.429500
# 12           AL     -0.416500
# 13           HI     -0.409500
# 14           NJ     -0.405364
# 15           IL     -0.402125
# 16           AZ     -0.399400
# 17           NC     -0.398500
# 18           FL     -0.398000
# 19           GA     -0.393286
# 20           CA     -0.390067
# 21           MD     -0.390000
# 22           TN     -0.390000
# 23           RI     -0.375750
# 24           WA     -0.374200
# 25           NY     -0.373476
# 26           IN     -0.372000
# 27           NM     -0.370600
# 28           PA     -0.357250
# 29           OH     -0.356800
# 30           CT     -0.348143
# 31           VA     -0.347444
# 32           CO     -0.347167
# 33           OR     -0.343857
# 34           MN     -0.324833
# 35           MI     -0.316875
# 36           NV     -0.296200
# 37           DE     -0.290333
# 38           KS     -0.266000
# 39           ME     -0.263500

# %%
myquery = '''
SELECT bill_type, COUNT(*) as count
FROM bills
GROUP BY bill_type
    HAVING bill_type LIKE 
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#    state_abbrev  avg_ideology
# 0            MS     -0.519000
# 1            WI     -0.511333
# 2            MO     -0.510000
# 3            KY     -0.500000
# 4            DC     -0.491000
# 5            LA     -0.483500
# 6            VI     -0.474000
# 7            TX     -0.469769
# 8            SC     -0.467000
# 9            PR     -0.463000
# 10           MA     -0.430182
# 11           VT     -0.429500
# 12           AL     -0.416500
# 13           HI     -0.409500
# 14           NJ     -0.405364
# 15           IL     -0.402125
# 16           AZ     -0.399400
# 17           NC     -0.398500
# 18           FL     -0.398000
# 19           GA     -0.393286
# 20           CA     -0.390067
# 21           MD     -0.390000
# 22           TN     -0.390000
# 23           RI     -0.375750
# 24           WA     -0.374200
# 25           NY     -0.373476
# 26           IN     -0.372000
# 27           NM     -0.370600
# 28           PA     -0.357250
# 29           OH     -0.356800
# 30           CT     -0.348143
# 31           VA     -0.347444
# 32           CO     -0.347167
# 33           OR     -0.343857
# 34           MN     -0.324833
# 35           MI     -0.316875
# 36           NV     -0.296200
# 37           DE     -0.290333
# 38           KS     -0.266000
# 39           ME     -0.263500

# %% [markdown]
# * ORDER BY: sort, DESC in decending order

# %%
myquery = '''
SELECT state_abbrev,
    AVG(left_right_ideology) AS avg_ideology
FROM members
WHERE party = 'Democrat'
GROUP BY state_abbrev
    HAVING AVG(left_right_ideology) < -.25
ORDER BY avg_ideology
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#    state_abbrev  avg_ideology
# 0            MS     -0.519000
# 1            WI     -0.511333
# 2            MO     -0.510000
# 3            KY     -0.500000
# 4            DC     -0.491000
# 5            LA     -0.483500
# 6            VI     -0.474000
# 7            TX     -0.469769
# 8            SC     -0.467000
# 9            PR     -0.463000
# 10           MA     -0.430182
# 11           VT     -0.429500
# 12           AL     -0.416500
# 13           HI     -0.409500
# 14           NJ     -0.405364
# 15           IL     -0.402125
# 16           AZ     -0.399400
# 17           NC     -0.398500
# 18           FL     -0.398000
# 19           GA     -0.393286
# 20           CA     -0.390067
# 21           MD     -0.390000
# 22           TN     -0.390000
# 23           RI     -0.375750
# 24           WA     -0.374200
# 25           NY     -0.373476
# 26           IN     -0.372000
# 27           NM     -0.370600
# 28           PA     -0.357250
# 29           OH     -0.356800
# 30           CT     -0.348143
# 31           VA     -0.347444
# 32           CO     -0.347167
# 33           OR     -0.343857
# 34           MN     -0.324833
# 35           MI     -0.316875
# 36           NV     -0.296200
# 37           DE     -0.290333
# 38           KS     -0.266000
# 39           ME     -0.263500

# %% [markdown]
# * LIMIT num: only the first unm rows (head())

# %%
myquery = '''
SELECT state_abbrev,
    AVG(left_right_ideology) AS avg_ideology
FROM members
WHERE party = 'Democrat'
GROUP BY state_abbrev
    HAVING AVG(left_right_ideology) < -.25
ORDER BY avg_ideology
LIMIT 10 OFFSET 5
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#   state_abbrev  avg_ideology
# 0           LA     -0.483500
# 1           VI     -0.474000
# 2           TX     -0.469769
# 3           SC     -0.467000
# 4           PR     -0.463000
# 5           MA     -0.430182
# 6           VT     -0.429500
# 7           AL     -0.416500
# 8           HI     -0.409500
# 9           NJ     -0.405364

# %% [markdown]
# * JOIN: merges

# %%
# Who has more terms? Democrat or Republican?

myquery = '''
SELECT
    m.party,
    COUNT(*) AS tenure
FROM members m
INNER JOIN terms t
    ON m.bioguide_id = t.bioguide_id
GROUP BY m.party
ORDER BY tenure DESC
'''
pd.read_sql_query(myquery, con=engine)
# Out:
#          party  tenure
# 0     Democrat    1742
# 1   Republican    1490
# 2  Independent      25

# %% [markdown]
# * Subqueries
